# %% [markdown]
# # importing the important libraries

# %%
import wandb
wandb.login()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ma23m020 (snehalma23m020-iit-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# 2025-03-17 21:43:17.909076: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-17 21:43:17.909588: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-17 21:43:17.912567: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-17 21:43:17.922845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742227997.937912  150237 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742227997.942187  150237 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-17 21:43:17.958974: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Question 1 : Download the fashion-MNIST dataset and plot 1 sample image for each class as shown in the grid below. Use from keras.datasets import fashion_mnist for getting the fashion mnist dataset.

# %% [markdown]
# # Step 1 : Load the dataset

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Step 2 : The class labels

# %%
LABEL_NAMES = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", 
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# # Step 3 : To visualize one sample from each category

# %%
def display_unique_samples(images, labels, category_names): 
    seen_classes = set()
    plt.figure(figsize=(15, 12))
    sample_count = 0

    for idx in range(len(images)):
        category = labels[idx]
        if category not in seen_classes:
            seen_classes.add(category)
            sample_count += 1
            plt.subplot(5, 2, sample_count) # subplot
            plt.imshow(images[idx], cmap='CMRmap') 
            plt.title(category_names[category])
            plt.axis("off")

            if sample_count == 10:  # all 10 categories
                break

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Step 4 : Display images

# %%
display_unique_samples(train_images, train_labels, LABEL_NAMES)

# %% [markdown]
# # Step 5 : Function to prepare image lists for Wandb

# %%
def prepare_wandb_images(start_idx, end_idx, images, labels, label_names):
    img_list = [
        wandb.Image(images[i], caption=f"{label_names[labels[i]]} (idx={i})") 
        for i in range(start_idx, end_idx)
    ]
    return img_list

# %% [markdown]
# # step 6 : Initialise Wandb to plot in wandb as required , Loading images and then End Wandb session

# %%
wandb.init(project="DLassignment1", name="Q1")
image_set_1 = prepare_wandb_images(0, 18, train_images, train_labels, LABEL_NAMES)
image_set_2 = prepare_wandb_images(18, 36, train_images, train_labels, LABEL_NAMES)
wandb.log({"First Batch": image_set_1, "Second Batch": image_set_2})
wandb.finish()
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_120455-i0eea4f4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i0eea4f4' target="_blank">Q1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i0eea4f4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i0eea4f4</a>
#  View run <strong style="color:#cdcd00">Q1</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i0eea4f4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i0eea4f4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 36 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_120455-i0eea4f4/logs</code>

# %% [markdown]
# # Q2 : Implement a feedforward neural network which takes images from the fashion-mnist data as input and outputs a probability distribution over the 10 classes .Your code should be flexible such that it is easy to change the number of hidden layers and the number of neurons in each hidden layer.

# %% [markdown]
# # Firstly Repeat Step 1 and Step 2 as in Question 1

# %% [markdown]
# # step 1 :Loading the dataset

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Step 2 : Defining the labels

# %%
LABEL_NAMES = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# # Step 3 : Normalizing and reshaping the dataset

# %%
##################### Normalising & Reshaping
train_images = train_images.reshape(-1, 28*28) / 255.0
test_images = test_images.reshape(-1, 28*28) / 255.0

##################### One hot encoding of labels
train_labels_onehot = np.eye(10)[train_labels]
test_labels_onehot = np.eye(10)[test_labels]

# %% [markdown]
# # Step 4 : Implementing the class of Neural Network

# %%
class CustomNN:
    # a constructor for default initilisation
    def __init__(self, layers, lr=0.1):
        self.layers = layers
        self.lr = lr
        self.num_layers = len(layers)
        
        # Using "He initialization" to initialize weights 
        self.weights = [np.random.randn(layers[i], layers[i+1]) * np.sqrt(2.0 / layers[i])
                        for i in range(self.num_layers - 1)]
        self.biases = [np.zeros((1, layers[i+1])) for i in range(self.num_layers - 1)]


    @staticmethod
    def relu(x):
        return np.maximum(0, x)

    @staticmethod
    def softmax(x):
        exp_vals = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_vals / np.sum(exp_vals, axis=1, keepdims=True)


    def forward_pass(self, X):
        self.intermediate_outputs, self.activations = [], [X]
        output = X
        
        for idx in range(len(self.weights) - 1):
            z = output @ self.weights[idx] + self.biases[idx]
            self.intermediate_outputs.append(z)
            output = self.relu(z)
            self.activations.append(output)
        
        final_z = output @ self.weights[-1] + self.biases[-1]
        self.intermediate_outputs.append(final_z)
        final_output = self.softmax(final_z)
        self.activations.append(final_output)
        
        return final_output
    
    
    #def compute_loss(self, predicted, actual):
    #    return -np.sum(actual * np.log(predicted + 1e-8)) / actual.shape[0]
    

    def compute_loss(self, predicted, actual):
        return -np.mean(np.sum(actual * np.log(predicted + 1e-8), axis=1))


    def backward_pass(self, predicted, actual):
        batch_size = actual.shape[0]
        delta = (predicted - actual) / batch_size
        weight_grads, bias_grads = [None] * len(self.weights), [None] * len(self.biases)
        weight_grads[-1] = self.activations[-2].T @ delta
        bias_grads[-1] = np.sum(delta, axis=0, keepdims=True)
        
        for i in range(len(self.weights) - 2, -1, -1):
            delta = (delta @ self.weights[i+1].T) * (self.intermediate_outputs[i] > 0)
            weight_grads[i] = self.activations[i].T @ delta
            bias_grads[i] = np.sum(delta, axis=0, keepdims=True)
        
        for i in range(len(self.weights)):
            self.weights[i] -= self.lr * weight_grads[i]
            self.biases[i] -= self.lr * bias_grads[i]


    def predict(self, X):
        return np.argmax(self.forward_pass(X), axis=1)

# %% [markdown]
# # Step 5 : Defining the architecture and parameters

# %% [markdown]
# # flexibility !!

# %%
hidden_layers = [128, 64, 64]  # Modify this list to change the number of hidden layers and neurons
model_layers = [784] + hidden_layers + [10]  # Input layer, hidden layers, output layer

# %%
# Training Parameters
epochs = 20
batch_size = 64
num_batches = train_images.shape[0] // batch_size

# %% [markdown]
# # Step 6 : Initialising Wandb , training the neural network and finding the test accuracy

# %%
wandb.init(project="DLassignment1", name="Q2")


neural_net = CustomNN(model_layers, lr=0.1)
# Training
for epoch in range(epochs):
    indices = np.random.permutation(train_images.shape[0])
    X_shuffled, y_shuffled = train_images[indices], train_labels_onehot[indices]
    total_loss = 0
    
    for batch in range(num_batches):
        start, end = batch * batch_size, (batch + 1) * batch_size
        X_batch, y_batch = X_shuffled[start:end], y_shuffled[start:end]

        predictions = neural_net.forward_pass(X_batch)
        total_loss += neural_net.compute_loss(predictions, y_batch)
        neural_net.backward_pass(predictions, y_batch)

    avg_loss = total_loss / num_batches
    train_acc = np.mean(neural_net.predict(train_images) == train_labels)

    print(f"Epoch {epoch+1}/{epochs} | Loss: {avg_loss:.4f} | Training Accuracy: {train_acc:.4f}")
    wandb.log({"Epoch": epoch+1, "Loss": avg_loss, "Training Accuracy": train_acc})

# Test accuracy 
test_acc = np.mean(neural_net.predict(test_images) == test_labels)
print(f"Final Test Accuracy: {test_acc:.4f}")
wandb.log({"Test Accuracy": test_acc})
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_132126-k411akna</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/k411akna' target="_blank">Q2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/k411akna' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/k411akna</a>
# Epoch 1/20 | Loss: 0.5853 | Training Accuracy: 0.8395
# Epoch 2/20 | Loss: 0.4115 | Training Accuracy: 0.8607
# Epoch 3/20 | Loss: 0.3694 | Training Accuracy: 0.8796
# Epoch 4/20 | Loss: 0.3409 | Training Accuracy: 0.8839
# Epoch 5/20 | Loss: 0.3238 | Training Accuracy: 0.8842
# Epoch 6/20 | Loss: 0.3087 | Training Accuracy: 0.8962
# Epoch 7/20 | Loss: 0.2945 | Training Accuracy: 0.8887
# Epoch 8/20 | Loss: 0.2836 | Training Accuracy: 0.8943
# Epoch 9/20 | Loss: 0.2740 | Training Accuracy: 0.9000
# Epoch 10/20 | Loss: 0.2659 | Training Accuracy: 0.9064
# Epoch 11/20 | Loss: 0.2582 | Training Accuracy: 0.9102
# Epoch 12/20 | Loss: 0.2504 | Training Accuracy: 0.9134
# Epoch 13/20 | Loss: 0.2433 | Training Accuracy: 0.9047
# Epoch 14/20 | Loss: 0.2353 | Training Accuracy: 0.9158
# Epoch 15/20 | Loss: 0.2349 | Training Accuracy: 0.9198
# Epoch 16/20 | Loss: 0.2275 | Training Accuracy: 0.9172
# Epoch 17/20 | Loss: 0.2225 | Training Accuracy: 0.9185
# Epoch 18/20 | Loss: 0.2155 | Training Accuracy: 0.9259
# Epoch 19/20 | Loss: 0.2092 | Training Accuracy: 0.9055
# Epoch 20/20 | Loss: 0.2075 | Training Accuracy: 0.9244
# Final Test Accuracy: 0.8805

# %% [markdown]
# # Step 7 : Visualisations

# %%
# test samples for visualization
test_samples = [10, 20, 45, 80, 980, 60]
results_table = []

# Set up figure
fig, axs = plt.subplots(len(test_samples), 2, figsize=(10, len(test_samples) * 3))

for i, sample_idx in enumerate(test_samples):
    prob_distribution = neural_net.forward_pass(test_images[sample_idx:sample_idx+1])
    predicted_label = np.argmax(prob_distribution)

    prob_text = ""
    for j, prob in enumerate(prob_distribution[0]):
        prob_text += f"{LABEL_NAMES[j]}: {prob:.4f}\n"
        results_table.append([sample_idx, LABEL_NAMES[j], prob])

    # Display sample image
    axs[i, 0].imshow(test_images[sample_idx].reshape(28, 28), cmap='magma')
    axs[i, 0].set_title(f"Test Sample {sample_idx}\nTrue: {LABEL_NAMES[test_labels[sample_idx]]}\nPred: {LABEL_NAMES[predicted_label]}")
    axs[i, 0].axis('off')

    # Display class probabilities
    axs[i, 1].barh(LABEL_NAMES, prob_distribution[0], color='coral')
    axs[i, 1].set_xlim(0, 1)
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_title("Class Probabilities")

    for j, prob in enumerate(prob_distribution[0]):
        axs[i, 1].text(prob + 0.01, j, f"{prob:.4f}", va='center')

    print(f"\nTest Sample {sample_idx} Probability Distribution:")
    print(prob_text)

plt.tight_layout()
plt.show()

# Log probability distributions to W&B
probability_table = wandb.Table(data=results_table, columns=["Sample Index", "Class", "Probability"])
wandb.log({"Sample Probability Distributions": probability_table})

wandb.finish()
# Out:
# Test Sample 10 Probability Distribution:
# T-shirt/top: 0.0018
# Trouser: 0.0014
# Pullover: 0.4473
# Dress: 0.0000
# Coat: 0.4877
# Sandal: 0.0000
# Shirt: 0.0616
# Sneaker: 0.0000
# Bag: 0.0001
# Ankle boot: 0.0000
#
#
# Test Sample 20 Probability Distribution:
# T-shirt/top: 0.0124
# Trouser: 0.0000
# Pullover: 0.9746
# Dress: 0.0000
# Coat: 0.0006
# Sandal: 0.0000
# Shirt: 0.0120
# Sneaker: 0.0000
# Bag: 0.0003
# Ankle boot: 0.0000
#
#
# Test Sample 45 Probability Distribution:
# T-shirt/top: 0.0000
# Trouser: 0.0000
# Pullover: 0.0000
# Dress: 0.0000
# Coat: 0.0000
# Sandal: 0.0031
# Shirt: 0.0000
# Sneaker: 0.9817
# Bag: 0.0000
# Ankle boot: 0.0152
#
#
# Test Sample 80 Probability Distribution:
# T-shirt/top: 0.0000
# Trouser: 0.9994
# Pullover: 0.0000
# Dress: 0.0004
# Coat: 0.0001
# Sandal: 0.0000
# Shirt: 0.0000
# Sneaker: 0.0000
# Bag: 0.0000
# Ankle boot: 0.0000
#
#
# Test Sample 980 Probability Distribution:
# T-shirt/top: 0.0000
# Trouser: 0.0000
# Pullover: 0.0000
# Dress: 0.0000
# Coat: 0.0000
# Sandal: 0.0000
# Shirt: 0.0000
# Sneaker: 0.0028
# Bag: 0.0000
# Ankle boot: 0.9972
#
#
# Test Sample 60 Probability Distribution:
# T-shirt/top: 0.0000
# Trouser: 0.0000
# Pullover: 0.0000
# Dress: 0.0000
# Coat: 0.0000
# Sandal: 0.0002
# Shirt: 0.0000
# Sneaker: 0.9998
# Bag: 0.0000
# Ankle boot: 0.0001
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>Loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Training Accuracy</td><td>▁▃▄▅▅▆▅▅▆▆▇▇▆▇█▇▇█▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>20</td></tr><tr><td>Loss</td><td>0.20747</td></tr><tr><td>Test Accuracy</td><td>0.8805</td></tr><tr><td>Training Accuracy</td><td>0.92435</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/k411akna' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/k411akna</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_132126-k411akna/logs</code>

# %% [markdown]
# # Q3 : Implement the backpropagation algorithm with support for the following optimisation functions
#     sgd
#     momentum based gradient descent
#     nesterov accelerated gradient descent
#     rmsprop
#     adam
#     nadam
#
# (12 marks for the backpropagation framework and 2 marks for each of the optimisation algorithms above)
#
# We will check the code for implementation and ease of use (e.g., how easy it is to add a new optimisation algorithm such as Eve). Note that the code should be flexible enough to work with different batch sizes.
# ﻿

# %% [markdown]
# # Step 1 : Load the dataset

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Step 2 : The class labels

# %%
LABEL_NAMES = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# # Step 3 : Preprocessing and one hot encoding

# %%
# Preprocess images
train_images = train_images.reshape(-1, 28 * 28) / 255.0
test_images = test_images.reshape(-1, 28 * 28) / 255.0

# Convert labels to one-hot encoding
train_labels_onehot = np.eye(10)[train_labels]
test_labels_onehot = np.eye(10)[test_labels]

# %% [markdown]
# # Step 4 : Algorithm for the optimisers

# %%
class NeuralNetwork:
    def __init__(self, layers):
        # Initialize the neural network with given layer sizes.
        self.layers = layers
        self.weights = [np.random.randn(layers[i], layers[i+1]) * np.sqrt(2.0 / layers[i]) for i in range(len(layers)-1)]
        self.biases = [np.zeros((1, layers[i+1])) for i in range(len(layers)-1)]

    def relu(self, x):
        # Applies ReLU activation.
        return np.maximum(0, x)

    def softmax(self, x):
        # Applies softmax activation for multi-class classification.
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)

    def forward(self, X):
        # Performs forward propagation.
        self.cache_z, self.cache_a = [], [X]
        activation = X
        for i in range(len(self.weights) - 1):
            z = activation @ self.weights[i] + self.biases[i]
            self.cache_z.append(z)
            activation = self.relu(z)
            self.cache_a.append(activation)

        final_z = activation @ self.weights[-1] + self.biases[-1]
        self.cache_z.append(final_z)
        output = self.softmax(final_z)
        self.cache_a.append(output)
        return output

    def compute_loss(self, y_pred, y_true):
        # Computes cross-entropy loss.
        return -np.mean(np.sum(y_true * np.log(y_pred + 1e-8), axis=1))

    def backward(self, y_pred, y_true):
        # Computes gradients using backpropagation.
        batch_size = y_true.shape[0]
        dW, db = [None] * len(self.weights), [None] * len(self.biases)

        delta = (y_pred - y_true) / batch_size
        dW[-1], db[-1] = self.cache_a[-2].T @ delta, np.sum(delta, axis=0, keepdims=True)

        for i in range(len(self.weights)-2, -1, -1):
            delta = delta @ self.weights[i+1].T * (self.cache_z[i] > 0)
            dW[i], db[i] = self.cache_a[i].T @ delta, np.sum(delta, axis=0, keepdims=True)

        return dW, db

# %% [markdown]
# # Step 5 : Optimisers

# %%
class Optimizer:
    # Base optimizer class to handle initialization of parameters.
    def __init__(self, lr):  # where lr:learning rate
        self.lr = lr

    def update(sts, biases, dW, db, t):
        raise NotImplementedError("Subclasses should implement this method.")


class SGD(Optimizer):
    # Stochastic Gradient Descent Optimizer.
    def __init__(self, lr=0.01):
        super().__init__(lr)

    def update(self, wts,bias, dW, db, t):
        for i in range(len(wts)):
            wts[i] -= self.lr * dW[i]
            bias[i]  -= self.lr * db[i]


class Momentum(Optimizer):
    # Momentum-based Gradient Descent.
    def __init__(self, lr=0.01, momentum=0.9):
        super().__init__(lr)
        self.momentum = momentum
        self.state = {}

    def update(self, wts, bias, dW, db, t):
        if not self.state:
            self.state['vw'] = [np.zeros_like(w) for w in wts]
            self.state['vb'] = [np.zeros_like(b) for b in bias]

        for i in range(len(wts)):
            self.state['vw'][i] = self.momentum * self.state['vw'][i] + self.lr * dW[i]
            self.state['vb'][i] = self.momentum * self.state['vb'][i] + self.lr * db[i]
            wts[i] -= self.state['vw'][i]
            bias[i]  -= self.state['vb'][i]


class Nesterov(Momentum):
    # Nesterov Accelerated Gradient Descent.
    def update(self, wts, bias, dW, db, t):
        if not self.state:
            self.state['vw'] = [np.zeros_like(w) for w in wts]
            self.state['vb'] = [np.zeros_like(b) for b in bias]

        for i in range(len(wts)):
            prev_vw = self.state['vw'][i].copy()
            prev_vb = self.state['vb'][i].copy()

            self.state['vw'][i] = self.momentum * self.state['vw'][i] + self.lr * dW[i]
            self.state['vb'][i] = self.momentum * self.state['vb'][i] + self.lr * db[i]

            wts[i] -= -self.momentum * prev_vw + (1 + self.momentum) * self.state['vw'][i]
            bias[i]  -= -self.momentum * prev_vb + (1 + self.momentum) * self.state['vb'][i]


class RMSProp(Optimizer):
    # RMSProp Optimizer
    def __init__(self, lr=0.001, decay_rate=0.9, epsilon=1e-8):
        super().__init__(lr)
        self.decay_rate = decay_rate
        self.epsilon = epsilon
        self.state = {}

    def update(self, wts, bias, dW, db, t):
        if not self.state:
            self.state['Sw'] = [np.zeros_like(w) for w in wts]
            self.state['Sb'] = [np.zeros_like(b) for b in bias]

        for i in range(len(wts)):
            self.state['Sw'][i] = self.decay_rate * self.state['Sw'][i] + (1 - self.decay_rate) * (dW[i] ** 2)
            self.state['Sb'][i] = self.decay_rate * self.state['Sb'][i] + (1 - self.decay_rate) * (db[i] ** 2)

            wts[i] -= self.lr * dW[i] / (np.sqrt(self.state['Sw'][i]) + self.epsilon)
            bias[i]  -= self.lr * db[i] / (np.sqrt(self.state['Sb'][i]) + self.epsilon)


class Adam(Optimizer):
    # Adam Optimizer
    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
        super().__init__(lr)
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.state = {}

    def update(self, wts, bias, dW, db, t):
        if not self.state:
            self.state['mw'] = [np.zeros_like(w) for w in wts]
            self.state['vw'] = [np.zeros_like(w) for w in wts]
            self.state['mb'] = [np.zeros_like(b) for b in bias]
            self.state['vb'] = [np.zeros_like(b) for b in bias]

        for i in range(len(wts)):
            self.state['mw'][i] = self.beta1 * self.state['mw'][i] + (1 - self.beta1) * dW[i]
            self.state['vw'][i] = self.beta2 * self.state['vw'][i] + (1 - self.beta2) * (dW[i] ** 2)
            self.state['mb'][i] = self.beta1 * self.state['mb'][i] + (1 - self.beta1) * db[i]
            self.state['vb'][i] = self.beta2 * self.state['vb'][i] + (1 - self.beta2) * (db[i] ** 2)

            m_hat_w = self.state['mw'][i] / (1 - self.beta1 ** t)
            v_hat_w = self.state['vw'][i] / (1 - self.beta2 ** t)
            m_hat_b = self.state['mb'][i] / (1 - self.beta1 ** t)
            v_hat_b = self.state['vb'][i] / (1 - self.beta2 ** t)

            wts[i] -= self.lr * m_hat_w / (np.sqrt(v_hat_w) + self.epsilon)
            bias[i]  -= self.lr * m_hat_b / (np.sqrt(v_hat_b) + self.epsilon)


class Nadam(Adam):
    # Nadam Optimizer (Adam with Nesterov momentum).
    def update(self, wts, bias, dW, db, t):
        if not self.state:
            self.state['mw'] = [np.zeros_like(w) for w in wts]
            self.state['vw'] = [np.zeros_like(w) for w in wts]
            self.state['mb'] = [np.zeros_like(b) for b in bias]
            self.state['vb'] = [np.zeros_like(b) for b in bias]

        for i in range(len(wts)):
            self.state['mw'][i] = self.beta1 * self.state['mw'][i] + (1 - self.beta1) * dW[i]
            self.state['vw'][i] = self.beta2 * self.state['vw'][i] + (1 - self.beta2) * (dW[i] ** 2)
            self.state['mb'][i] = self.beta1 * self.state['mb'][i] + (1 - self.beta1) * db[i]
            self.state['vb'][i] = self.beta2 * self.state['vb'][i] + (1 - self.beta2) * (db[i] ** 2)

            m_hat = self.state['mw'][i] / (1 - self.beta1 ** t)
            v_hat = self.state['vw'][i] / (1 - self.beta2 ** t)
            m_hat_b = self.state['mb'][i] / (1 - self.beta1 ** t)
            v_hat_b = self.state['vb'][i] / (1 - self.beta2 ** t)

            wts[i] -= self.lr * (self.beta1 * m_hat + (1 - self.beta1) * dW[i] / (1 - self.beta1 ** t)) / (np.sqrt(v_hat) + self.epsilon)
            bias[i]  -= self.lr * (self.beta1 * m_hat_b + (1 - self.beta1) * db[i] / (1 - self.beta1 ** t)) / (np.sqrt(v_hat_b) + self.epsilon)

# %% [markdown]
# # You can add any new optimisation algorithm by just defining a new class and add it to optimizers_dict.

# %% [markdown]
# # Step 6 : Defining a dictionary

# %%
# Define a dictionary mapping optimizer names to functions that return a new optimizer instance.
optimizers_dict = {
    "SGD": lambda: SGD(lr=0.01),
    "Momentum": lambda: Momentum(lr=0.01, momentum=0.9),
    "Nesterov": lambda: Nesterov(lr=0.01, momentum=0.9),
    "RMSProp": lambda: RMSProp(lr=0.001, decay_rate=0.9),
    "Adam": lambda: Adam(lr=0.001, beta1=0.9, beta2=0.999),
    "Nadam": lambda: Nadam(lr=0.001, beta1=0.9, beta2=0.999)
}

# %% [markdown]
# # Step 7 : Common training parameters

# %%
num_epochs = 10
batch_size = 64
num_batches = train_images.shape[0] // batch_size



layer_sizes = [784, 128, 64, 10]

# %% [markdown]
# # Step 8 : Training and Testing

# %%
# To store summary results for each optimizer.
results = []

# Loop over each optimizer and run a separate training experiment.
for opt_name, opt_fn in optimizers_dict.items():
    # Initialize a new wandb run for each optimizer.
    run = wandb.init(project="DLassignment1", 
                     name=f"Q3_{opt_name}", 
                     reinit=True, 
                     config={
                         "optimizer": opt_name,
                         "num_epochs": num_epochs,
                         "batch_size": batch_size,
                         "layer_sizes": layer_sizes
                     })
    
    # Initializing
    nn = NeuralNetwork(layer_sizes)
    optimizer = opt_fn()
    
    global_step = 1
    epoch_losses = []
    
    print(f"\nStarting training with optimizer: {opt_name}")
    for epoch in range(num_epochs):

        # Shuffle training data 
        perm = np.random.permutation(train_images.shape[0])
        X_train_shuffled = train_images[perm]
        y_train_onehot_shuffled = train_labels_onehot[perm]
        
        epoch_loss = 0

        for i in range(num_batches):
            start = i * batch_size
            end = start + batch_size
            X_batch = X_train_shuffled[start:end]
            y_batch = y_train_onehot_shuffled[start:end]
            
            # Forward pass.
            Y_pred = nn.forward(X_batch)
            loss = nn.compute_loss(Y_pred, y_batch)
            epoch_loss += loss
            
            # Backward pass: compute gradients.
            dW, db = nn.backward(Y_pred, y_batch)
            
            # Update parameters 
            optimizer.update(nn.weights, nn.biases, dW, db, global_step)
            global_step += 1
        
        avg_loss = epoch_loss / num_batches
        epoch_losses.append(avg_loss)
        
        # Evaluate training accuracy on the entire training set.
        train_predictions = np.argmax(nn.forward(train_images), axis=1)
        train_accuracy = np.mean(train_predictions == train_labels)
        
        print(f"{opt_name} | Epoch {epoch+1}/{num_epochs} - Loss: {avg_loss:.4f} - Train Accuracy: {train_accuracy:.4f}")
        wandb.log({"epoch": epoch+1, "loss": avg_loss, "train_accuracy": train_accuracy})
    
    # Evaluate on the test set.
    test_predictions = np.argmax(nn.forward(test_images), axis=1)
    test_accuracy = np.mean(test_predictions == test_labels)
    print(f"{opt_name} | Test Accuracy: {test_accuracy:.4f}")
    wandb.log({"test_accuracy": test_accuracy})
    
    # Save final results for this optimizer.
    results.append({
        "Optimizer": opt_name,
        "Final Train Accuracy": train_accuracy,
        "Test Accuracy": test_accuracy,
        "Final Loss": avg_loss
    })
    
    run.finish()
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_164204-p6mfrd6i</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/p6mfrd6i' target="_blank">Q3_SGD</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/p6mfrd6i' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/p6mfrd6i</a>
# Starting training with optimizer: SGD
# SGD | Epoch 1/10 - Loss: 0.8353 - Train Accuracy: 0.8113
# SGD | Epoch 2/10 - Loss: 0.5302 - Train Accuracy: 0.8280
# SGD | Epoch 3/10 - Loss: 0.4786 - Train Accuracy: 0.8450
# SGD | Epoch 4/10 - Loss: 0.4509 - Train Accuracy: 0.8520
# SGD | Epoch 5/10 - Loss: 0.4324 - Train Accuracy: 0.8547
# SGD | Epoch 6/10 - Loss: 0.4169 - Train Accuracy: 0.8578
# SGD | Epoch 7/10 - Loss: 0.4040 - Train Accuracy: 0.8577
# SGD | Epoch 8/10 - Loss: 0.3948 - Train Accuracy: 0.8660
# SGD | Epoch 9/10 - Loss: 0.3850 - Train Accuracy: 0.8714
# SGD | Epoch 10/10 - Loss: 0.3765 - Train Accuracy: 0.8703
# SGD | Test Accuracy: 0.8499
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▅▆▆▆▆▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.37654</td></tr><tr><td>test_accuracy</td><td>0.8499</td></tr><tr><td>train_accuracy</td><td>0.87028</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_SGD</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/p6mfrd6i' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/p6mfrd6i</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_164204-p6mfrd6i/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_165640-991fdkzr</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/991fdkzr' target="_blank">Q3_Momentum</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/991fdkzr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/991fdkzr</a>
# Starting training with optimizer: Momentum
# Momentum | Epoch 1/10 - Loss: 0.5550 - Train Accuracy: 0.8518
# Momentum | Epoch 2/10 - Loss: 0.3981 - Train Accuracy: 0.8716
# Momentum | Epoch 3/10 - Loss: 0.3638 - Train Accuracy: 0.8705
# Momentum | Epoch 4/10 - Loss: 0.3373 - Train Accuracy: 0.8796
# Momentum | Epoch 5/10 - Loss: 0.3199 - Train Accuracy: 0.8899
# Momentum | Epoch 6/10 - Loss: 0.3056 - Train Accuracy: 0.8991
# Momentum | Epoch 7/10 - Loss: 0.2941 - Train Accuracy: 0.8956
# Momentum | Epoch 8/10 - Loss: 0.2845 - Train Accuracy: 0.8940
# Momentum | Epoch 9/10 - Loss: 0.2730 - Train Accuracy: 0.9086
# Momentum | Epoch 10/10 - Loss: 0.2654 - Train Accuracy: 0.9022
# Momentum | Test Accuracy: 0.8731
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▃▄▆▇▆▆█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.26535</td></tr><tr><td>test_accuracy</td><td>0.8731</td></tr><tr><td>train_accuracy</td><td>0.90217</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_Momentum</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/991fdkzr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/991fdkzr</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_165640-991fdkzr/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_171104-2hl2rq1d</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2hl2rq1d' target="_blank">Q3_Nesterov</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2hl2rq1d' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2hl2rq1d</a>
# Starting training with optimizer: Nesterov
# Nesterov | Epoch 1/10 - Loss: 0.5419 - Train Accuracy: 0.8500
# Nesterov | Epoch 2/10 - Loss: 0.3938 - Train Accuracy: 0.8724
# Nesterov | Epoch 3/10 - Loss: 0.3549 - Train Accuracy: 0.8787
# Nesterov | Epoch 4/10 - Loss: 0.3315 - Train Accuracy: 0.8901
# Nesterov | Epoch 5/10 - Loss: 0.3107 - Train Accuracy: 0.8864
# Nesterov | Epoch 6/10 - Loss: 0.2993 - Train Accuracy: 0.8995
# Nesterov | Epoch 7/10 - Loss: 0.2877 - Train Accuracy: 0.8941
# Nesterov | Epoch 8/10 - Loss: 0.2772 - Train Accuracy: 0.9059
# Nesterov | Epoch 9/10 - Loss: 0.2670 - Train Accuracy: 0.9047
# Nesterov | Epoch 10/10 - Loss: 0.2583 - Train Accuracy: 0.9109
# Nesterov | Test Accuracy: 0.8821
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▄▄▆▅▇▆▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.2583</td></tr><tr><td>test_accuracy</td><td>0.8821</td></tr><tr><td>train_accuracy</td><td>0.91087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_Nesterov</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2hl2rq1d' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2hl2rq1d</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_171104-2hl2rq1d/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_172017-yydnefbr</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yydnefbr' target="_blank">Q3_RMSProp</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yydnefbr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yydnefbr</a>
# Starting training with optimizer: RMSProp
# RMSProp | Epoch 1/10 - Loss: 0.5267 - Train Accuracy: 0.8629
# RMSProp | Epoch 2/10 - Loss: 0.3759 - Train Accuracy: 0.8738
# RMSProp | Epoch 3/10 - Loss: 0.3408 - Train Accuracy: 0.8875
# RMSProp | Epoch 4/10 - Loss: 0.3212 - Train Accuracy: 0.8961
# RMSProp | Epoch 5/10 - Loss: 0.3036 - Train Accuracy: 0.8882
# RMSProp | Epoch 6/10 - Loss: 0.2920 - Train Accuracy: 0.9035
# RMSProp | Epoch 7/10 - Loss: 0.2832 - Train Accuracy: 0.8998
# RMSProp | Epoch 8/10 - Loss: 0.2750 - Train Accuracy: 0.9076
# RMSProp | Epoch 9/10 - Loss: 0.2661 - Train Accuracy: 0.8980
# RMSProp | Epoch 10/10 - Loss: 0.2624 - Train Accuracy: 0.9133
# RMSProp | Test Accuracy: 0.8773
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▄▆▅▇▆▇▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.26236</td></tr><tr><td>test_accuracy</td><td>0.8773</td></tr><tr><td>train_accuracy</td><td>0.91335</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_RMSProp</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yydnefbr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yydnefbr</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_172017-yydnefbr/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_173140-le6nxjxh</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/le6nxjxh' target="_blank">Q3_Adam</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/le6nxjxh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/le6nxjxh</a>
# Starting training with optimizer: Adam
# Adam | Epoch 1/10 - Loss: 0.5090 - Train Accuracy: 0.8643
# Adam | Epoch 2/10 - Loss: 0.3755 - Train Accuracy: 0.8831
# Adam | Epoch 3/10 - Loss: 0.3359 - Train Accuracy: 0.8857
# Adam | Epoch 4/10 - Loss: 0.3109 - Train Accuracy: 0.8962
# Adam | Epoch 5/10 - Loss: 0.2950 - Train Accuracy: 0.8955
# Adam | Epoch 6/10 - Loss: 0.2801 - Train Accuracy: 0.9027
# Adam | Epoch 7/10 - Loss: 0.2698 - Train Accuracy: 0.9086
# Adam | Epoch 8/10 - Loss: 0.2586 - Train Accuracy: 0.9078
# Adam | Epoch 9/10 - Loss: 0.2500 - Train Accuracy: 0.9112
# Adam | Epoch 10/10 - Loss: 0.2392 - Train Accuracy: 0.9123
# Adam | Test Accuracy: 0.8780
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▅▄▃▂▂▂▂▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▄▄▆▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.23924</td></tr><tr><td>test_accuracy</td><td>0.878</td></tr><tr><td>train_accuracy</td><td>0.9123</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_Adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/le6nxjxh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/le6nxjxh</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_173140-le6nxjxh/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_174553-sjtrg7eh</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/sjtrg7eh' target="_blank">Q3_Nadam</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/sjtrg7eh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/sjtrg7eh</a>
# Starting training with optimizer: Nadam
# Nadam | Epoch 1/10 - Loss: 0.4858 - Train Accuracy: 0.8656
# Nadam | Epoch 2/10 - Loss: 0.3653 - Train Accuracy: 0.8842
# Nadam | Epoch 3/10 - Loss: 0.3272 - Train Accuracy: 0.8919
# Nadam | Epoch 4/10 - Loss: 0.3048 - Train Accuracy: 0.8888
# Nadam | Epoch 5/10 - Loss: 0.2878 - Train Accuracy: 0.8970
# Nadam | Epoch 6/10 - Loss: 0.2730 - Train Accuracy: 0.9018
# Nadam | Epoch 7/10 - Loss: 0.2626 - Train Accuracy: 0.9059
# Nadam | Epoch 8/10 - Loss: 0.2517 - Train Accuracy: 0.9041
# Nadam | Epoch 9/10 - Loss: 0.2425 - Train Accuracy: 0.9138
# Nadam | Epoch 10/10 - Loss: 0.2337 - Train Accuracy: 0.9111
# Nadam | Test Accuracy: 0.8770
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▅▄▃▃▂▂▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▄▆▆▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.23373</td></tr><tr><td>test_accuracy</td><td>0.877</td></tr><tr><td>train_accuracy</td><td>0.91112</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q3_Nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/sjtrg7eh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/sjtrg7eh</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_174553-sjtrg7eh/logs</code>

# %% [markdown]
# # Step 9 : Sumarising the results

# %%
# Create a wandb Table with the summary results.
summary_table = wandb.Table(columns=["Optimizer", "Final Train Accuracy", "Test Accuracy", "Final Loss"])
for res in results:
    summary_table.add_data(res["Optimizer"], res["Final Train Accuracy"], res["Test Accuracy"], res["Final Loss"])

# summary comparison.
summary_run = wandb.init(project="DLassignment1", name="Q3_summary", reinit=True)
wandb.log({"Optimizer Comparison": summary_table})
summary_run.finish()

# Optionally, print the summary table.
print("\nSummary of Performance of the Optimizers :")
for res in results:
    print(f"{res['Optimizer']:10s} | Train Acc: {res['Final Train Accuracy']:.4f} | Test Acc: {res['Test Accuracy']:.4f} | Final Loss: {res['Final Loss']:.4f}")
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250316_180249-5943edux</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/5943edux' target="_blank">Q3_summary</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/5943edux' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/5943edux</a>
#  View run <strong style="color:#cdcd00">Q3_summary</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/5943edux' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/5943edux</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250316_180249-5943edux/logs</code>
# Summary of Performance of the Optimizers :
# SGD        | Train Acc: 0.8703 | Test Acc: 0.8499 | Final Loss: 0.3765
# Momentum   | Train Acc: 0.9022 | Test Acc: 0.8731 | Final Loss: 0.2654
# Nesterov   | Train Acc: 0.9109 | Test Acc: 0.8821 | Final Loss: 0.2583
# RMSProp    | Train Acc: 0.9133 | Test Acc: 0.8773 | Final Loss: 0.2624
# Adam       | Train Acc: 0.9123 | Test Acc: 0.8780 | Final Loss: 0.2392
# Nadam      | Train Acc: 0.9111 | Test Acc: 0.8770 | Final Loss: 0.2337

# %% [markdown]
# # Q4: Use the sweep functionality provided by wandb to find the best values for the hyperparameters listed below. Use the standard train/test split of fashion_mnist (use (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()). Keep 10% of the training data aside as validation data for this hyperparameter search. Here are some suggestions for different values to try for hyperparameters. As you can quickly see that this leads to an exponential number of combinations. You will have to think about strategies to do this hyperparameter search efficiently. Check out the options provided by wandb.sweep and write down what strategy you chose and why.
#
#     number of epochs: 5, 10
#     number of hidden layers: 3, 4, 5
#     size of every hidden layer: 32, 64, 128
#     weight decay (L2 regularisation): 0, 0.0005, 0.5
#     learning rate: 1e-3, 1 e-4
#     optimizer: sgd, momentum, nesterov, rmsprop, adam, nadam
#     batch size: 16, 32, 64
#     weight initialisation: random, Xavier
#     activation functions: sigmoid, tanh, ReLU

# %% [markdown]
# # Step 1 : Loading the dataset

# %%
(train_images_full, train_labels_full), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Step 2 : Split off 10% of the training set as validation data

# %%
val_split = int(0.1 * train_images_full.shape[0]) # 10% split

val_images = train_images_full[:val_split]
val_labels = train_labels_full[:val_split]
train_images = train_images_full[val_split:]
train_labels = train_labels_full[val_split:]

# %% [markdown]
# # Step 3 : Flatten and normalize images

# %%
train_images = train_images.reshape(-1, 28*28) / 255.0
val_images   = val_images.reshape(-1, 28*28)   / 255.0
test_images  = test_images.reshape(-1, 28*28)  / 255.0

# %% [markdown]
# # Step 4 : One hot encoding of the labels

# %%
train_labels_oh = np.eye(10)[train_labels]
val_labels_oh   = np.eye(10)[val_labels]
test_labels_oh  = np.eye(10)[test_labels]

# %% [markdown]
# # Step 5 : Different values of Hyperparamters (given)

# %%
sweep_config = {
    'method': 'bayes',  # or 'grid', 'bayes'
    'metric': {'name': 'val_loss', 'goal': 'minimize'},
    'parameters': {
        'epochs': {'values': [5,10]},
        'num_hidden_layers': {'values': [3, 4, 5]},
        'hidden_layer_size': {'values': [32, 64, 128]},
        'weight_decay': {'values': [0, 0.0005, 0.5]},
        'learning_rate': {'values': [1e-3, 1e-4]},
        'optimizer': {'values': ['sgd', 'momentum', 'nesterov', 'rmsprop', 'adam', 'nadam']},
        'batch_size': {'values': [16, 32, 64]},
        'weight_init': {'values': ['random', 'xavier']},
        'activation_function': {'values': ['sigmoid', 'tanh', 'relu']}
    }
}

# %% [markdown]
# # Step 6 : Xavier Initialisation

# %%
def xavier_init(fan_in, fan_out):
    """Xavier/Glorot initialization."""
    bound = np.sqrt(6 / (fan_in + fan_out))
    return np.random.uniform(-bound, bound, (fan_in, fan_out))

# %% [markdown]
# # Step 7 : Neural Network

# %%
class NeuralNetwork:
    def __init__(self, input_size, hidden_layers, hidden_units, output_size, init_method='random', activation_func='relu', reg_strength=0.0):
        self.hidden_layers = hidden_layers
        self.hidden_units = hidden_units
        self.activation_name = activation_func
        self.reg_strength = reg_strength
        
        # Activation Functions
        if activation_func == 'relu':
            self.activate = lambda x: np.maximum(0, x)
            self.activation_derivative = lambda x: (x > 0).astype(float)
        elif activation_func == 'sigmoid':
            self.activate = lambda x: 1.0 / (1.0 + np.exp(-x))
            self.activation_derivative = lambda x: self.activate(x) * (1 - self.activate(x))
        elif activation_func == 'tanh':
            self.activate = lambda x: np.tanh(x)
            self.activation_derivative = lambda x: 1 - np.tanh(x)**2
        else:
            raise ValueError("Unsupported activation function")
        
        # Network Architecture
        layer_sizes = [input_size] + [hidden_units] * hidden_layers + [output_size]
        self.weights = []
        self.biases = []
        
        for i in range(len(layer_sizes) - 1):
            fan_in, fan_out = layer_sizes[i], layer_sizes[i + 1]
            if init_method == 'xavier':
                weight_matrix = xavier_init(fan_in, fan_out)
            else:
                weight_matrix = np.random.randn(fan_in, fan_out) * 0.01
            bias_vector = np.zeros((1, fan_out))
            
            self.weights.append(weight_matrix)
            self.biases.append(bias_vector)
    

    
    def softmax(self, values):
        exp_values = np.exp(values - np.max(values, axis=1, keepdims=True))
        return exp_values / np.sum(exp_values, axis=1, keepdims=True)
    
    def forward_pass(self, input_data):
        self.layer_inputs = []
        self.activations = [input_data]
        activation = input_data
        
        for i in range(len(self.weights) - 1):
            weighted_sum = activation.dot(self.weights[i]) + self.biases[i]
            self.layer_inputs.append(weighted_sum)
            activation = self.activate(weighted_sum)
            self.activations.append(activation)
        
        final_weighted_sum = activation.dot(self.weights[-1]) + self.biases[-1]
        self.layer_inputs.append(final_weighted_sum)
        output = self.softmax(final_weighted_sum)
        self.activations.append(output)
        return output
    


    def compute_cost(self, predicted_output, true_labels):
        num_samples = true_labels.shape[0]
        log_likelihoods = -np.sum(true_labels * np.log(predicted_output + 1e-8)) / num_samples
        
        # L2 Regularization
        reg_term = 0
        if self.reg_strength > 0:
            reg_term = (self.reg_strength / (2 * num_samples)) * sum(np.sum(W**2) for W in self.weights)
        
        return log_likelihoods + reg_term
    



    def backpropagate(self, predicted_output, true_labels):
        #Computes gradients for weights and biases.
        num_samples = true_labels.shape[0]
        weight_gradients = [None] * len(self.weights)
        bias_gradients = [None] * len(self.biases)
        
        # Compute gradient at output layer
        error = (predicted_output - true_labels) / num_samples
        weight_gradients[-1] = self.activations[-2].T.dot(error)
        bias_gradients[-1] = np.sum(error, axis=0, keepdims=True)
        
        # Compute gradients for hidden layers
        for i in range(len(self.weights) - 2, -1, -1):
            error = error.dot(self.weights[i + 1].T) * self.activation_derivative(self.layer_inputs[i])
            weight_gradients[i] = self.activations[i].T.dot(error)
            bias_gradients[i] = np.sum(error, axis=0, keepdims=True)
        
        # Apply L2 Regularization
        if self.reg_strength > 0:
            for i in range(len(self.weights)):
                weight_gradients[i] += (self.reg_strength * self.weights[i]) / num_samples
        
        return weight_gradients, bias_gradients

# %% [markdown]
# # Step 8 : Training the model

# %%
def train_model_sweep(config=None):
    with wandb.init(config=config):
        config = wandb.config
        
        # Step 1.  Build the MLP
        mlp = NeuralNetwork(input_dim=784,num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
        
        # Step 2. Choose the optimizer
        if config.optimizer == 'sgd':
            optimizer = SGD(learning_rate=config.learning_rate)
        elif config.optimizer == 'momentum':
            optimizer = Momentum(learning_rate=config.learning_rate, momentum=0.9)
        elif config.optimizer == 'nesterov':
            optimizer = Nesterov(learning_rate=config.learning_rate, momentum=0.9)
        elif config.optimizer == 'rmsprop':
            optimizer = RMSProp(learning_rate=config.learning_rate, decay_rate=0.9)
        elif config.optimizer == 'adam':
            optimizer = Adam(learning_rate=config.learning_rate, beta1=0.9, beta2=0.999)
        elif config.optimizer == 'nadam':
            optimizer = Nadam(learning_rate=config.learning_rate, beta1=0.9, beta2=0.999)
        else:
            raise ValueError("Unknown optimizer")
        
        # Step 3. Training loop
        global_step = 1
        for epoch in range(config.epochs):
            
            num_samples = train_images.shape[0]   # Shuffle training data
            indices = np.random.permutation(num_samples)
            X_train_shuffled = train_images[indices]
            y_train_shuffled = train_labels_oh[indices]
            
            for start_idx in range(0, num_samples, config.batch_size):
                end_idx = start_idx + config.batch_size
                X_batch = X_train_shuffled[start_idx:end_idx]
                y_batch = y_train_shuffled[start_idx:end_idx]
                
              
                y_pred = mlp.forward(X_batch)    # Forward
                
                
                dW, db = mlp.backward(y_pred, y_batch) # Compute gradients 

              
                optimizer.update(mlp.weights, mlp.biases, dW, db, global_step)     # Optimizer update
                global_step += 1
            
        
            val_pred = mlp.forward(val_images)    # Evaluate on validation set
            val_loss = mlp.compute_loss(val_pred, val_labels_oh)
            val_acc  = np.mean(np.argmax(val_pred, axis=1) == val_labels)
            


            # Step 4 : Log to wandb
            wandb.log({
                "epoch": epoch+1,
                "val_loss": val_loss,
                "val_accuracy": val_acc
            })
        
            # Step 5 : Evaluate on test set
            test_pred = mlp.forward(test_images)
            test_loss = mlp.compute_loss(test_pred, test_labels_oh)
            test_acc  = np.mean(np.argmax(test_pred, axis=1) == test_labels)
        
            wandb.log({"test_loss": test_loss, "test_accuracy": test_acc})
        
    
        run_name = f"hl_{config.num_hidden_layers}_bs_{config.batch_size}_act_{config.activation_function}_opt_{config.optimizer}"
        wandb.run.name = run_name
        
        print(f"Run {run_name} finished with val_acc={val_acc:.4f}, test_acc={test_acc:.4f}")

# %% [markdown]
# # Step 9 : Creating the sweep

# %%
# SGD Optimizer
class SGD:
    def __init__(self, learning_rate=0.01):
        self.learning_rate = learning_rate
        
    def update(self, weights, biases, dW, db, t):
        for i in range(len(weights)):
            weights[i] -= self.learning_rate * dW[i]
            biases[i]  -= self.learning_rate * db[i]

# Momentum-Based Gradient Descent
class Momentum:
    def __init__(self, learning_rate=0.01, momentum=0.9):
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.vw = None
        self.vb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.vw is None:
            self.vw = [np.zeros_like(w) for w in weights]
            self.vb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            self.vw[i] = self.momentum * self.vw[i] + self.learning_rate * dW[i]
            self.vb[i] = self.momentum * self.vb[i] + self.learning_rate * db[i]
            weights[i] -= self.vw[i]
            biases[i]  -= self.vb[i]

# Nesterov Accelerated Gradient Descent
class Nesterov:
    def __init__(self, learning_rate=0.01, momentum=0.9):
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.vw = None
        self.vb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.vw is None:
            self.vw = [np.zeros_like(w) for w in weights]
            self.vb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            # Save previous velocity
            v_prev_w = self.vw[i].copy()
            v_prev_b = self.vb[i].copy()
            # Update velocity
            self.vw[i] = self.momentum * self.vw[i] + self.learning_rate * dW[i]
            self.vb[i] = self.momentum * self.vb[i] + self.learning_rate * db[i]
            # Nesterov update (lookahead)
            weights[i] -= -self.momentum * v_prev_w + (1 + self.momentum) * self.vw[i]
            biases[i]  -= -self.momentum * v_prev_b + (1 + self.momentum) * self.vb[i]

# RMSProp Optimizer
class RMSProp:
    def __init__(self, learning_rate=0.001, decay_rate=0.9, epsilon=1e-8):
        self.learning_rate = learning_rate
        self.decay_rate = decay_rate
        self.epsilon = epsilon
        self.Sw = None
        self.Sb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.Sw is None:
            self.Sw = [np.zeros_like(w) for w in weights]
            self.Sb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            self.Sw[i] = self.decay_rate * self.Sw[i] + (1 - self.decay_rate) * (dW[i] ** 2)
            self.Sb[i] = self.decay_rate * self.Sb[i] + (1 - self.decay_rate) * (db[i] ** 2)
            weights[i] -= self.learning_rate * dW[i] / (np.sqrt(self.Sw[i]) + self.epsilon)
            biases[i]  -= self.learning_rate * db[i] / (np.sqrt(self.Sb[i]) + self.epsilon)

# Adam Optimizer
class Adam:
    def __init__(self, learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
        self.learning_rate = learning_rate
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.mw = None
        self.vw = None
        self.mb = None
        self.vb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.mw is None:
            self.mw = [np.zeros_like(w) for w in weights]
            self.vw = [np.zeros_like(w) for w in weights]
            self.mb = [np.zeros_like(b) for b in biases]
            self.vb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            self.mw[i] = self.beta1 * self.mw[i] + (1 - self.beta1) * dW[i]
            self.vw[i] = self.beta2 * self.vw[i] + (1 - self.beta2) * (dW[i] ** 2)
            self.mb[i] = self.beta1 * self.mb[i] + (1 - self.beta1) * db[i]
            self.vb[i] = self.beta2 * self.vb[i] + (1 - self.beta2) * (db[i] ** 2)
            
            m_hat_w = self.mw[i] / (1 - self.beta1 ** t)
            v_hat_w = self.vw[i] / (1 - self.beta2 ** t)
            m_hat_b = self.mb[i] / (1 - self.beta1 ** t)
            v_hat_b = self.vb[i] / (1 - self.beta2 ** t)
            
            weights[i] -= self.learning_rate * m_hat_w / (np.sqrt(v_hat_w) + self.epsilon)
            biases[i]  -= self.learning_rate * m_hat_b / (np.sqrt(v_hat_b) + self.epsilon)

# Nadam Optimizer (Adam with Nesterov momentum) - Corrected Bias Update
class Nadam:
    def __init__(self, learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
        self.learning_rate = learning_rate
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.mw = None
        self.vw = None
        self.mb = None
        self.vb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.mw is None:
            self.mw = [np.zeros_like(w) for w in weights]
            self.vw = [np.zeros_like(w) for w in weights]
            self.mb = [np.zeros_like(b) for b in biases]
            self.vb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            self.mw[i] = self.beta1 * self.mw[i] + (1 - self.beta1) * dW[i]
            self.vw[i] = self.beta2 * self.vw[i] + (1 - self.beta2) * (dW[i] ** 2)
            self.mb[i] = self.beta1 * self.mb[i] + (1 - self.beta1) * db[i]
            self.vb[i] = self.beta2 * self.vb[i] + (1 - self.beta2) * (db[i] ** 2)
            
            m_hat = self.mw[i] / (1 - self.beta1 ** t)
            v_hat = self.vw[i] / (1 - self.beta2 ** t)
            m_hat_b = self.mb[i] / (1 - self.beta1 ** t)
            v_hat_b = self.vb[i] / (1 - self.beta2 ** t)
            
            weights[i] -= self.learning_rate * (self.beta1 * m_hat + (1 - self.beta1) * dW[i] / (1 - self.beta1 ** t)) / (np.sqrt(v_hat) + self.epsilon)
            # Corrected: use v_hat_b for bias update
            biases[i]  -= self.learning_rate * (self.beta1 * m_hat_b + (1 - self.beta1) * db[i] / (1 - self.beta1 ** t)) / (np.sqrt(v_hat_b) + self.epsilon)

# %%
# 1. Load Fashion-MNIST
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# 2. Split off 10% of the training set as validation data
val_split = int(0.1 * X_train_full.shape[0])
X_val = X_train_full[:val_split]
y_val = y_train_full[:val_split]
X_train = X_train_full[val_split:]
y_train = y_train_full[val_split:]

# 3. Flatten and normalize images (28x28 -> 784) in [0,1]
X_train = X_train.reshape(-1, 28*28) / 255.0
X_val   = X_val.reshape(-1, 28*28)   / 255.0
X_test  = X_test.reshape(-1, 28*28)  / 255.0

# 4. One-hot encode labels
def one_hot(y, num_classes=10):
    return np.eye(num_classes)[y]

y_train_oh = one_hot(y_train)
y_val_oh   = one_hot(y_val)
y_test_oh  = one_hot(y_test)

# %%
sweep_config = {
    'method': 'bayes',  # or 'grid', 'bayes'
    'metric': {
      'name': 'val_loss', 
      'goal': 'minimize' 
    },
    'parameters': {
        'epochs': {
            'values': [5, 10]
        },
        'num_hidden_layers': {
            'values': [3, 4, 5]
        },
        'hidden_layer_size': {
            'values': [32, 64, 128]
        },
        'weight_decay': {
            'values': [0, 0.0005, 0.5]
        },
        'learning_rate': {
            'values': [1e-3, 1e-4]
        },
        'optimizer': {
            'values': ['sgd', 'momentum', 'nesterov', 'rmsprop', 'adam', 'nadam']
        },
        'batch_size': {
            'values': [16, 32, 64]
        },
        'weight_init': {
            'values': ['random', 'xavier']
        },
        'activation_function': {
            'values': ['sigmoid', 'tanh', 'relu']
        }
    }
}

# %%
#Xavier/Glorot initialization.
def xavier_init(fan_in, fan_out):
    limit = np.sqrt(6 / (fan_in + fan_out))
    return np.random.uniform(-limit, limit, (fan_in, fan_out))

class SimpleMLP:
    def __init__(self, input_dim, num_hidden_layers, hidden_size, output_dim,weight_init='random', activation='relu', weight_decay=0.0):
        self.num_hidden_layers = num_hidden_layers
        self.hidden_size = hidden_size
        self.activation_name = activation
        self.weight_decay = weight_decay
        
        # Activation
        if activation == 'relu':
            self.activation = lambda x: np.maximum(0, x)
            self.activation_deriv = lambda x: (x > 0).astype(float)
        elif activation == 'sigmoid':
            self.activation = lambda x: 1.0 / (1.0 + np.exp(-x))
            self.activation_deriv = lambda x: self.activation(x)*(1 - self.activation(x))
        elif activation == 'tanh':
            self.activation = lambda x: np.tanh(x)
            self.activation_deriv = lambda x: 1 - np.tanh(x)**2
        else:
            raise ValueError("Unsupported activation")

        # Build architecture
        layer_dims = [input_dim] + [hidden_size]*num_hidden_layers + [output_dim]
        self.weights = []
        self.biases  = []
        
        for i in range(len(layer_dims) - 1):
            fan_in  = layer_dims[i]
            fan_out = layer_dims[i+1]
            if weight_init == 'xavier':
                W = xavier_init(fan_in, fan_out)
            else:
                # simple random normal
                W = np.random.randn(fan_in, fan_out)*0.01
            b = np.zeros((1, fan_out))
            self.weights.append(W)
            self.biases.append(b)
    
    def softmax(self, x):
        exps = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exps / np.sum(exps, axis=1, keepdims=True)
    
    def forward(self, X):
        self.zs = []
        self.activations = [X]
        A = X
        for i in range(len(self.weights)-1):
            z = A.dot(self.weights[i]) + self.biases[i]
            self.zs.append(z)
            A = self.activation(z)
            self.activations.append(A)
        # Output layer
        z = A.dot(self.weights[-1]) + self.biases[-1]
        self.zs.append(z)
        out = self.softmax(z)
        self.activations.append(out)
        return out
    
    def compute_loss(self, y_pred, y_true):
        m = y_true.shape[0]
        log_likelihood = -np.sum(y_true * np.log(y_pred + 1e-8)) / m
        
        # L2 regularization
        l2_reg = 0
        if self.weight_decay > 0:
            for W in self.weights:
                l2_reg += np.sum(W**2)
            l2_reg = (self.weight_decay / (2*m)) * l2_reg
        
        return log_likelihood + l2_reg
    
    def backward(self, y_pred, y_true):
        m = y_true.shape[0]
        dW = [None]*len(self.weights)
        db = [None]*len(self.biases)
        
        # Output layer
        delta = (y_pred - y_true) / m
        dW[-1] = self.activations[-2].T.dot(delta)
        db[-1] = np.sum(delta, axis=0, keepdims=True)
        
        # Hidden layers
        for i in range(len(self.weights)-2, -1, -1):
            delta = delta.dot(self.weights[i+1].T) * self.activation_deriv(self.zs[i])
            dW[i] = self.activations[i].T.dot(delta)
            db[i] = np.sum(delta, axis=0, keepdims=True)
        
        # L2 penalty
        if self.weight_decay > 0:
            for i in range(len(self.weights)):
                dW[i] += (self.weight_decay * self.weights[i]) / m
        
        return dW, db

# %%
def train_model_sweep(config=None):
    with wandb.init(config=config):
        config = wandb.config
        
        # 1. Build the MLP
        mlp = SimpleMLP(
            input_dim=784,
            num_hidden_layers=config.num_hidden_layers,
            hidden_size=config.hidden_layer_size,
            output_dim=10,
            weight_init=config.weight_init,
            activation=config.activation_function,
            weight_decay=config.weight_decay
        )
        
        # 2. Choose the optimizer
        if config.optimizer == 'sgd':
            optimizer = SGD(learning_rate=config.learning_rate)
        elif config.optimizer == 'momentum':
            optimizer = Momentum(learning_rate=config.learning_rate, momentum=0.9)
        elif config.optimizer == 'nesterov':
            optimizer = Nesterov(learning_rate=config.learning_rate, momentum=0.9)
        elif config.optimizer == 'rmsprop':
            optimizer = RMSProp(learning_rate=config.learning_rate, decay_rate=0.9)
        elif config.optimizer == 'adam':
            optimizer = Adam(learning_rate=config.learning_rate, beta1=0.9, beta2=0.999)
        elif config.optimizer == 'nadam':
            optimizer = Nadam(learning_rate=config.learning_rate, beta1=0.9, beta2=0.999)
        else:
            raise ValueError("Unknown optimizer")
        
        # 3. Training loop
        global_step = 1
        for epoch in range(config.epochs):
            # Shuffle training data
            num_samples = X_train.shape[0]
            indices = np.random.permutation(num_samples)
            X_train_shuffled = X_train[indices]
            y_train_shuffled = y_train_oh[indices]
            
            for start_idx in range(0, num_samples, config.batch_size):
                end_idx = start_idx + config.batch_size
                X_batch = X_train_shuffled[start_idx:end_idx]
                y_batch = y_train_shuffled[start_idx:end_idx]
                
                # Forward
                y_pred = mlp.forward(X_batch)
                
                # Compute gradients (no update yet)
                dW, db = mlp.backward(y_pred, y_batch)
                
                # Optimizer update
                optimizer.update(mlp.weights, mlp.biases, dW, db, global_step)
                global_step += 1
            
            # Evaluate on validation set
            val_pred = mlp.forward(X_val)
            val_loss = mlp.compute_loss(val_pred, y_val_oh)
            val_acc  = np.mean(np.argmax(val_pred, axis=1) == y_val)
            
            # Log to wandb
            wandb.log({
                "epoch": epoch+1,
                "val_loss": val_loss,
                "val_accuracy": val_acc
            })
        
            # Evaluate on test set
            test_pred = mlp.forward(X_test)
            test_loss = mlp.compute_loss(test_pred, y_test_oh)
            test_acc  = np.mean(np.argmax(test_pred, axis=1) == y_test)
        
            wandb.log({"test_loss": test_loss, "test_accuracy": test_acc})
        
        # Giving the run a descriptive name
        run_name = f"hl_{config.num_hidden_layers}_bs_{config.batch_size}_act_{config.activation_function}_opt_{config.optimizer}"
        wandb.run.name = run_name
        
        print(f"Run {run_name} finished with val_acc={val_acc:.4f}, test_acc={test_acc:.4f}")

# %%
# Create the sweep in W&B
sweep_id = wandb.sweep(sweep_config, project="DLassignment1")

# Launch the sweep agent
# For example, we run 10 random combinations. Increase if desired.
wandb.agent(sweep_id, train_model_sweep, count=100)
# Out:
# Create sweep with ID: xydo45ye
# Sweep URL: https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye
# wandb: Agent Starting Run: bw65xsmf with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214350-bw65xsmf</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bw65xsmf' target="_blank">dauntless-sweep-1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bw65xsmf' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bw65xsmf</a>
# Run hl_3_bs_32_act_sigmoid_opt_adam finished with val_acc=0.8665, test_acc=0.8556
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▆▇██</td></tr><tr><td>test_loss</td><td>█▃▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.8556</td></tr><tr><td>test_loss</td><td>0.41447</td></tr><tr><td>val_accuracy</td><td>0.8665</td></tr><tr><td>val_loss</td><td>0.39228</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_act_sigmoid_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bw65xsmf' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bw65xsmf</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214350-bw65xsmf/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: g0fd3c3a with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nesterov
# wandb: 	weight_decay: 0
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214427-g0fd3c3a</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/g0fd3c3a' target="_blank">distinctive-sweep-2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/g0fd3c3a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/g0fd3c3a</a>
# Run hl_5_bs_32_act_relu_opt_nesterov finished with val_acc=0.0933, test_acc=0.1000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>test_loss</td><td>▁▂▇▆█</td></tr><tr><td>val_accuracy</td><td>▆▁▆█▁</td></tr><tr><td>val_loss</td><td>▁▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.1</td></tr><tr><td>test_loss</td><td>2.30261</td></tr><tr><td>val_accuracy</td><td>0.09333</td></tr><tr><td>val_loss</td><td>2.3028</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_32_act_relu_opt_nesterov</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/g0fd3c3a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/g0fd3c3a</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214427-g0fd3c3a/logs</code>
# wandb: Agent Starting Run: t8le3dfe with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214538-t8le3dfe</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/t8le3dfe' target="_blank">apricot-sweep-3</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/t8le3dfe' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/t8le3dfe</a>
# Run hl_5_bs_64_act_sigmoid_opt_adam finished with val_acc=0.7143, test_acc=0.7031
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▂▅▆█</td></tr><tr><td>test_loss</td><td>█▆▄▃▁</td></tr><tr><td>val_accuracy</td><td>▁▂▅▆█</td></tr><tr><td>val_loss</td><td>█▆▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.7031</td></tr><tr><td>test_loss</td><td>0.81526</td></tr><tr><td>val_accuracy</td><td>0.71433</td></tr><tr><td>val_loss</td><td>0.79851</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_sigmoid_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/t8le3dfe' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/t8le3dfe</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214538-t8le3dfe/logs</code>
# wandb: Agent Starting Run: msypc0zh with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214621-msypc0zh</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msypc0zh' target="_blank">swift-sweep-4</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msypc0zh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msypc0zh</a>
# Run hl_5_bs_64_act_tanh_opt_nadam finished with val_acc=0.8752, test_acc=0.8666
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▅▇█▇</td></tr><tr><td>test_loss</td><td>█▄▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▇█▆</td></tr><tr><td>val_loss</td><td>█▄▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.8666</td></tr><tr><td>test_loss</td><td>0.36226</td></tr><tr><td>val_accuracy</td><td>0.87517</td></tr><tr><td>val_loss</td><td>0.33283</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msypc0zh' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msypc0zh</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214621-msypc0zh/logs</code>
# wandb: Agent Starting Run: stjcq1ii with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214714-stjcq1ii</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/stjcq1ii' target="_blank">dashing-sweep-5</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/stjcq1ii' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/stjcq1ii</a>
# Run hl_3_bs_32_act_tanh_opt_rmsprop finished with val_acc=0.7922, test_acc=0.7801
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▁▂▇██████</td></tr><tr><td>test_loss</td><td>██▅▂▁▁▁▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▃▇███▇██</td></tr><tr><td>val_loss</td><td>██▅▂▁▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.7801</td></tr><tr><td>test_loss</td><td>0.62172</td></tr><tr><td>val_accuracy</td><td>0.79217</td></tr><tr><td>val_loss</td><td>0.59888</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_act_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/stjcq1ii' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/stjcq1ii</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214714-stjcq1ii/logs</code>
# wandb: Agent Starting Run: h7yj4k7g with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214752-h7yj4k7g</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/h7yj4k7g' target="_blank">visionary-sweep-6</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/h7yj4k7g' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/h7yj4k7g</a>
# Run hl_3_bs_64_act_tanh_opt_nadam finished with val_acc=0.8283, test_acc=0.8114
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▁▁▁▁▁▁▆██</td></tr><tr><td>test_loss</td><td>███████▃▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁▁▁▅██</td></tr><tr><td>val_loss</td><td>███████▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8114</td></tr><tr><td>test_loss</td><td>0.53129</td></tr><tr><td>val_accuracy</td><td>0.82833</td></tr><tr><td>val_loss</td><td>0.4972</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/h7yj4k7g' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/h7yj4k7g</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214752-h7yj4k7g/logs</code>
# wandb: Agent Starting Run: i2th4zpi with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214830-i2th4zpi</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i2th4zpi' target="_blank">frosty-sweep-7</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i2th4zpi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i2th4zpi</a>
# Run hl_3_bs_64_act_tanh_opt_rmsprop finished with val_acc=0.8863, test_acc=0.8722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▆▇▆▇▇█▇██</td></tr><tr><td>test_loss</td><td>█▃▂▃▂▂▁▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇▆▇▇█▇██</td></tr><tr><td>val_loss</td><td>█▃▂▃▂▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8722</td></tr><tr><td>test_loss</td><td>0.35568</td></tr><tr><td>val_accuracy</td><td>0.88633</td></tr><tr><td>val_loss</td><td>0.32074</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i2th4zpi' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/i2th4zpi</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214830-i2th4zpi/logs</code>
# wandb: Agent Starting Run: qi6deipu with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_214903-qi6deipu</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qi6deipu' target="_blank">gentle-sweep-8</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qi6deipu' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qi6deipu</a>
# Run hl_3_bs_64_act_tanh_opt_nadam finished with val_acc=0.8762, test_acc=0.8684
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▄▅▅▆▆▇▇██</td></tr><tr><td>test_loss</td><td>█▅▄▄▃▃▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▆▆▇▇██</td></tr><tr><td>val_loss</td><td>█▅▄▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8684</td></tr><tr><td>test_loss</td><td>0.37118</td></tr><tr><td>val_accuracy</td><td>0.87617</td></tr><tr><td>val_loss</td><td>0.34402</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qi6deipu' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qi6deipu</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_214903-qi6deipu/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vhxeqq8q with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215028-vhxeqq8q</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vhxeqq8q' target="_blank">dutiful-sweep-9</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vhxeqq8q' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vhxeqq8q</a>
# Run hl_3_bs_64_act_sigmoid_opt_nadam finished with val_acc=0.8498, test_acc=0.8334
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▃▆▇▇▇████</td></tr><tr><td>test_loss</td><td>█▅▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇▇▇████</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8334</td></tr><tr><td>test_loss</td><td>0.46548</td></tr><tr><td>val_accuracy</td><td>0.84983</td></tr><tr><td>val_loss</td><td>0.43126</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vhxeqq8q' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vhxeqq8q</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215028-vhxeqq8q/logs</code>
# wandb: Agent Starting Run: gq1mjat6 with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215144-gq1mjat6</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gq1mjat6' target="_blank">eternal-sweep-10</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gq1mjat6' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gq1mjat6</a>
# Run hl_3_bs_64_act_tanh_opt_nadam finished with val_acc=0.8503, test_acc=0.8331
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▃▁▂▁▃▇▇▄█▆</td></tr><tr><td>test_loss</td><td>██▇▇▄▂▂▅▁▃</td></tr><tr><td>val_accuracy</td><td>▃▁▃▃▄▇▇▄█▆</td></tr><tr><td>val_loss</td><td>████▅▂▂▆▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8331</td></tr><tr><td>test_loss</td><td>0.4701</td></tr><tr><td>val_accuracy</td><td>0.85033</td></tr><tr><td>val_loss</td><td>0.44197</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gq1mjat6' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gq1mjat6</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215144-gq1mjat6/logs</code>
# wandb: Agent Starting Run: gjpo0nk4 with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215259-gjpo0nk4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gjpo0nk4' target="_blank">northern-sweep-11</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gjpo0nk4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gjpo0nk4</a>
# Run hl_3_bs_64_act_sigmoid_opt_nadam finished with val_acc=0.6728, test_acc=0.6658
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>test_loss</td><td>█▆▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>val_loss</td><td>█▆▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.6658</td></tr><tr><td>test_loss</td><td>1.05443</td></tr><tr><td>val_accuracy</td><td>0.67283</td></tr><tr><td>val_loss</td><td>1.04371</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gjpo0nk4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/gjpo0nk4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215259-gjpo0nk4/logs</code>
# wandb: Agent Starting Run: l1vrpis2 with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215321-l1vrpis2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/l1vrpis2' target="_blank">woven-sweep-12</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/l1vrpis2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/l1vrpis2</a>
# Run hl_3_bs_64_act_relu_opt_nadam finished with val_acc=0.8743, test_acc=0.8632
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▄▄▆▆▇▇▆██</td></tr><tr><td>test_loss</td><td>█▅▅▃▃▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▆▆▇▇▆██</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8632</td></tr><tr><td>test_loss</td><td>0.37986</td></tr><tr><td>val_accuracy</td><td>0.87433</td></tr><tr><td>val_loss</td><td>0.34674</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/l1vrpis2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/l1vrpis2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215321-l1vrpis2/logs</code>
# wandb: Agent Starting Run: iiw14ebz with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215414-iiw14ebz</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/iiw14ebz' target="_blank">chocolate-sweep-13</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/iiw14ebz' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/iiw14ebz</a>
# Run hl_3_bs_32_act_sigmoid_opt_nadam finished with val_acc=0.7630, test_acc=0.7582
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>test_loss</td><td>█▆▄▃▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>val_loss</td><td>█▆▄▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.7582</td></tr><tr><td>test_loss</td><td>0.6794</td></tr><tr><td>val_accuracy</td><td>0.763</td></tr><tr><td>val_loss</td><td>0.67035</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/iiw14ebz' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/iiw14ebz</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215414-iiw14ebz/logs</code>
# wandb: Agent Starting Run: tt7z6wdt with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215622-tt7z6wdt</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tt7z6wdt' target="_blank">classic-sweep-14</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tt7z6wdt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tt7z6wdt</a>
# Run hl_3_bs_64_act_relu_opt_nadam finished with val_acc=0.8733, test_acc=0.8618
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>test_loss</td><td>█▅▃▃▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇█▇████</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8618</td></tr><tr><td>test_loss</td><td>0.39272</td></tr><tr><td>val_accuracy</td><td>0.87333</td></tr><tr><td>val_loss</td><td>0.36083</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tt7z6wdt' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tt7z6wdt</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_215622-tt7z6wdt/logs</code>
# wandb: Agent Starting Run: pgwqg6r3 with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_215711-pgwqg6r3</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/pgwqg6r3' target="_blank">youthful-sweep-15</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/pgwqg6r3' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/pgwqg6r3</a>
# Run hl_3_bs_64_act_tanh_opt_nadam finished with val_acc=0.8880, test_acc=0.8804
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▅▆▆▇▇█▇██</td></tr><tr><td>test_loss</td><td>█▅▄▄▃▂▁▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▇▇████</td></tr><tr><td>val_loss</td><td>█▄▄▄▃▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8804</td></tr><tr><td>test_loss</td><td>0.33558</td></tr><tr><td>val_accuracy</td><td>0.888</td></tr><tr><td>val_loss</td><td>0.30512</td></tr></table><br/></div></div>
# ...
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/q7cdr3xx' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/q7cdr3xx</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_233856-q7cdr3xx/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yqji18mc with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_234044-yqji18mc</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yqji18mc' target="_blank">happy-sweep-83</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yqji18mc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yqji18mc</a>
# Run hl_3_bs_16_act_sigmoid_opt_nadam finished with val_acc=0.8888, test_acc=0.8808
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▅▆▆▆▆▇▆▆█</td></tr><tr><td>test_loss</td><td>█▄▃▃▂▂▁▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▆▆▇▆▆█</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▂▁▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8808</td></tr><tr><td>test_loss</td><td>0.34051</td></tr><tr><td>val_accuracy</td><td>0.88883</td></tr><tr><td>val_loss</td><td>0.31405</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_16_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yqji18mc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/yqji18mc</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_234044-yqji18mc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: msyfrppc with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_234142-msyfrppc</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msyfrppc' target="_blank">astral-sweep-84</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msyfrppc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msyfrppc</a>
# Run hl_3_bs_64_act_sigmoid_opt_adam finished with val_acc=0.8778, test_acc=0.8681
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁▄▇▆█</td></tr><tr><td>test_loss</td><td>█▅▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄█▇█</td></tr><tr><td>val_loss</td><td>█▄▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.8681</td></tr><tr><td>test_loss</td><td>0.36827</td></tr><tr><td>val_accuracy</td><td>0.87783</td></tr><tr><td>val_loss</td><td>0.34006</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_act_sigmoid_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msyfrppc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/msyfrppc</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_234142-msyfrppc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: s442ge2j with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_234236-s442ge2j</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/s442ge2j' target="_blank">legendary-sweep-85</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/s442ge2j' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/s442ge2j</a>
# Run hl_3_bs_32_act_tanh_opt_rmsprop finished with val_acc=0.8733, test_acc=0.8616
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▃▁▇▆▅█▆▇▇▇</td></tr><tr><td>test_loss</td><td>▅█▂▂▃▁▃▁▂▁</td></tr><tr><td>val_accuracy</td><td>▃▁▇▆▄█▆█▇▇</td></tr><tr><td>val_loss</td><td>▆█▂▂▃▁▃▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8616</td></tr><tr><td>test_loss</td><td>0.38138</td></tr><tr><td>val_accuracy</td><td>0.87333</td></tr><tr><td>val_loss</td><td>0.34555</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_act_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/s442ge2j' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/s442ge2j</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_234236-s442ge2j/logs</code>
# wandb: Agent Starting Run: va89ultz with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_234436-va89ultz</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/va89ultz' target="_blank">feasible-sweep-86</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/va89ultz' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/va89ultz</a>
# Run hl_3_bs_32_act_sigmoid_opt_adam finished with val_acc=0.8780, test_acc=0.8733
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁▂▅▆▆▇██▇█</td></tr><tr><td>test_loss</td><td>█▇▄▃▂▁▂▁▂▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▇██▇██▇</td></tr><tr><td>val_loss</td><td>█▆▃▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8733</td></tr><tr><td>test_loss</td><td>0.35211</td></tr><tr><td>val_accuracy</td><td>0.878</td></tr><tr><td>val_loss</td><td>0.32501</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_act_sigmoid_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/va89ultz' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/va89ultz</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_234436-va89ultz/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ifsg6ohm with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_234643-ifsg6ohm</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ifsg6ohm' target="_blank">misty-sweep-87</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/xydo45ye</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ifsg6ohm' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ifsg6ohm</a>
# wandb: Ctrl + C detected. Stopping sweep.

# %%
sweep_id = wandb.sweep(sweep_config, project="DLassignment1")

wandb.agent(sweep_id, train_model_sweep, count=75)
# Out:
# Create sweep with ID: joi1yvr8
# Sweep URL: https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8
# wandb: Agent Starting Run: lkhz3jin with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: nesterov
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_213833-lkhz3jin</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/lkhz3jin' target="_blank">clear-sweep-1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/lkhz3jin' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/lkhz3jin</a>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#  View run <strong style="color:#cdcd00">clear-sweep-1</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/lkhz3jin' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/lkhz3jin</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_213833-lkhz3jin/logs</code>
# Run lkhz3jin errored:
# Traceback (most recent call last):
#   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
#     self._function()
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#
# wandb: ERROR Run lkhz3jin errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
# wandb: ERROR     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
# wandb: ERROR           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
# wandb: ERROR
# wandb: Agent Starting Run: ulkkl1sc with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_213839-ulkkl1sc</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ulkkl1sc' target="_blank">noble-sweep-2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ulkkl1sc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ulkkl1sc</a>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#  View run <strong style="color:#cdcd00">noble-sweep-2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ulkkl1sc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ulkkl1sc</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_213839-ulkkl1sc/logs</code>
# Run ulkkl1sc errored:
# Traceback (most recent call last):
#   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
#     self._function()
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#
# wandb: ERROR Run ulkkl1sc errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
# wandb: ERROR     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
# wandb: ERROR           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
# wandb: ERROR
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: f0i52b1c with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nesterov
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_213854-f0i52b1c</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/f0i52b1c' target="_blank">revived-sweep-3</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/joi1yvr8</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/f0i52b1c' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/f0i52b1c</a>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#  View run <strong style="color:#cdcd00">revived-sweep-3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/f0i52b1c' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/f0i52b1c</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_213854-f0i52b1c/logs</code>
# Run f0i52b1c errored:
# Traceback (most recent call last):
#   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
#     self._function()
#   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
#     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
#
# wandb: ERROR Run f0i52b1c errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "/home/snehal/Downloads/dl_ass1/dvenv/lib/python3.12/site-packages/wandb/agents/pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "/tmp/ipykernel_148851/100901616.py", line 6, in train_model_sweep
# wandb: ERROR     mlp = NeuralNetwork(num_hidden_layers=config.num_hidden_layers,hidden_size=config.hidden_layer_size,output_dim=10,weight_init=config.weight_init,activation=config.activation_function,weight_decay=config.weight_decay)
# wandb: ERROR           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# wandb: ERROR TypeError: NeuralNetwork.__init__() got an unexpected keyword argument 'num_hidden_layers'
# wandb: ERROR
# Detected 3 failed runs in the first 60 seconds, killing sweep.
# wandb: ERROR Detected 3 failed runs in the first 60 seconds, killing sweep.
# wandb: To disable this check set WANDB_AGENT_DISABLE_FLAPPING=true

# %%
sweep_id = wandb.sweep(sweep_config, project="DLassignment1")

wandb.agent(sweep_id, train_model_sweep, count=350)
# Out:
# Create sweep with ID: ysbgm4ic
# Sweep URL: https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic
# wandb: Agent Starting Run: xco7zcix with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141029-xco7zcix</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/xco7zcix' target="_blank">fiery-sweep-1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/xco7zcix' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/xco7zcix</a>
# Run hl_3_bs_16_act_tanh_opt_sgd finished with val_acc=0.0933, test_acc=0.1000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>█▅▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▅▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.1</td></tr><tr><td>test_loss</td><td>2.30256</td></tr><tr><td>val_accuracy</td><td>0.09333</td></tr><tr><td>val_loss</td><td>2.30258</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_16_act_tanh_opt_sgd</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/xco7zcix' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/xco7zcix</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141029-xco7zcix/logs</code>
# wandb: Agent Starting Run: 17uqfr7y with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141106-17uqfr7y</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/17uqfr7y' target="_blank">devout-sweep-2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/17uqfr7y' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/17uqfr7y</a>
# Run hl_3_bs_16_act_sigmoid_opt_momentum finished with val_acc=0.0973, test_acc=0.1000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>█▅▇▁▄</td></tr><tr><td>val_loss</td><td>▄▅█▁▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.1</td></tr><tr><td>test_loss</td><td>2.30282</td></tr><tr><td>val_accuracy</td><td>0.09733</td></tr><tr><td>val_loss</td><td>2.30306</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_bs_16_act_sigmoid_opt_momentum</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/17uqfr7y' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/17uqfr7y</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141106-17uqfr7y/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ji8jbpbk with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141133-ji8jbpbk</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ji8jbpbk' target="_blank">glorious-sweep-3</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ji8jbpbk' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ji8jbpbk</a>
# Run hl_5_bs_32_act_tanh_opt_rmsprop finished with val_acc=0.8862, test_acc=0.8742
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇▄▇▇▇▇██</td></tr><tr><td>val_loss</td><td>█▃▂▄▂▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8742</td></tr><tr><td>test_loss</td><td>0.35874</td></tr><tr><td>val_accuracy</td><td>0.88617</td></tr><tr><td>val_loss</td><td>0.32373</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_32_act_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ji8jbpbk' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ji8jbpbk</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141133-ji8jbpbk/logs</code>
# wandb: Agent Starting Run: vdq4bzj8 with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141211-vdq4bzj8</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vdq4bzj8' target="_blank">chocolate-sweep-4</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vdq4bzj8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vdq4bzj8</a>
# Run hl_5_bs_32_act_relu_opt_rmsprop finished with val_acc=0.8182, test_acc=0.8006
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▆▁▃▁█▇▃▇▇█</td></tr><tr><td>val_loss</td><td>▃█▇█▁▂▅▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8006</td></tr><tr><td>test_loss</td><td>0.56391</td></tr><tr><td>val_accuracy</td><td>0.81817</td></tr><tr><td>val_loss</td><td>0.52854</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_32_act_relu_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vdq4bzj8' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vdq4bzj8</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141211-vdq4bzj8/logs</code>
# wandb: Agent Starting Run: r2whedy4 with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141243-r2whedy4</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/r2whedy4' target="_blank">vocal-sweep-5</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/r2whedy4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/r2whedy4</a>
# Run hl_5_bs_64_act_tanh_opt_nadam finished with val_acc=0.8825, test_acc=0.8749
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇▇█▇▇</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▁▁▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8749</td></tr><tr><td>test_loss</td><td>0.35235</td></tr><tr><td>val_accuracy</td><td>0.8825</td></tr><tr><td>val_loss</td><td>0.32527</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/r2whedy4' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/r2whedy4</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141243-r2whedy4/logs</code>
# wandb: Agent Starting Run: leoyzp5f with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141327-leoyzp5f</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/leoyzp5f' target="_blank">toasty-sweep-6</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/leoyzp5f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/leoyzp5f</a>
# Run hl_5_bs_64_act_sigmoid_opt_adam finished with val_acc=0.8210, test_acc=0.8054
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇█████</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8054</td></tr><tr><td>test_loss</td><td>0.59081</td></tr><tr><td>val_accuracy</td><td>0.821</td></tr><tr><td>val_loss</td><td>0.56293</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_sigmoid_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/leoyzp5f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/leoyzp5f</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141327-leoyzp5f/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 0byfkkd2 with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141353-0byfkkd2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/0byfkkd2' target="_blank">brisk-sweep-7</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/0byfkkd2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/0byfkkd2</a>
# Run hl_5_bs_32_act_tanh_opt_nadam finished with val_acc=0.8753, test_acc=0.8679
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▇▆▅█▇▇▇▇</td></tr><tr><td>val_loss</td><td>█▄▃▃▄▁▂▁▂▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8679</td></tr><tr><td>test_loss</td><td>0.3799</td></tr><tr><td>val_accuracy</td><td>0.87533</td></tr><tr><td>val_loss</td><td>0.34935</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_32_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/0byfkkd2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/0byfkkd2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141353-0byfkkd2/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9pqvadye with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: random
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141420-9pqvadye</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9pqvadye' target="_blank">azure-sweep-8</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9pqvadye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9pqvadye</a>
# Run hl_5_bs_64_act_relu_opt_adam finished with val_acc=0.8805, test_acc=0.8705
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▆▇▇█▇█</td></tr><tr><td>val_loss</td><td>█▆▄▄▃▂▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8705</td></tr><tr><td>test_loss</td><td>0.38187</td></tr><tr><td>val_accuracy</td><td>0.8805</td></tr><tr><td>val_loss</td><td>0.3474</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_relu_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9pqvadye' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9pqvadye</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141420-9pqvadye/logs</code>
# wandb: Agent Starting Run: 9t1yc86b with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141525-9t1yc86b</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9t1yc86b' target="_blank">cool-sweep-9</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9t1yc86b' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9t1yc86b</a>
# Run hl_5_bs_64_act_tanh_opt_adam finished with val_acc=0.8805, test_acc=0.8730
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▆▅█▇▇▇█</td></tr><tr><td>val_loss</td><td>█▅▅▃▃▁▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.873</td></tr><tr><td>test_loss</td><td>0.36399</td></tr><tr><td>val_accuracy</td><td>0.8805</td></tr><tr><td>val_loss</td><td>0.34016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_tanh_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9t1yc86b' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/9t1yc86b</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141525-9t1yc86b/logs</code>
# wandb: Agent Starting Run: vlg3vpx1 with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layer_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141603-vlg3vpx1</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vlg3vpx1' target="_blank">glad-sweep-10</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vlg3vpx1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vlg3vpx1</a>
# Run hl_5_bs_64_act_relu_opt_nadam finished with val_acc=0.8782, test_acc=0.8658
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇▇█</td></tr><tr><td>val_loss</td><td>█▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>test_accuracy</td><td>0.8658</td></tr><tr><td>test_loss</td><td>0.37067</td></tr><tr><td>val_accuracy</td><td>0.87817</td></tr><tr><td>val_loss</td><td>0.3389</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vlg3vpx1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/vlg3vpx1</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141603-vlg3vpx1/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: cs1o8svd with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141635-cs1o8svd</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/cs1o8svd' target="_blank">fresh-sweep-11</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/cs1o8svd' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/cs1o8svd</a>
# Run hl_5_bs_64_act_relu_opt_adam finished with val_acc=0.8868, test_acc=0.8803
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅██▅▇██</td></tr><tr><td>val_loss</td><td>█▄▃▄▁▂▄▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8803</td></tr><tr><td>test_loss</td><td>0.34507</td></tr><tr><td>val_accuracy</td><td>0.88683</td></tr><tr><td>val_loss</td><td>0.32325</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_relu_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/cs1o8svd' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/cs1o8svd</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141635-cs1o8svd/logs</code>
# wandb: Agent Starting Run: tj8lvxhr with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141730-tj8lvxhr</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tj8lvxhr' target="_blank">solar-sweep-12</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tj8lvxhr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tj8lvxhr</a>
# Run hl_5_bs_64_act_relu_opt_nadam finished with val_acc=0.8857, test_acc=0.8831
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▆▃▇▆██▇</td></tr><tr><td>val_loss</td><td>█▅▃▂▅▁▃▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8831</td></tr><tr><td>test_loss</td><td>0.32962</td></tr><tr><td>val_accuracy</td><td>0.88567</td></tr><tr><td>val_loss</td><td>0.31791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tj8lvxhr' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tj8lvxhr</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141730-tj8lvxhr/logs</code>
# wandb: Agent Starting Run: ry4nqkyp with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_141840-ry4nqkyp</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ry4nqkyp' target="_blank">giddy-sweep-13</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ry4nqkyp' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ry4nqkyp</a>
# Run hl_5_bs_16_act_relu_opt_adam finished with val_acc=0.8803, test_acc=0.8734
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▆▅▄█▇▇██▇</td></tr><tr><td>val_loss</td><td>█▃▄▅▁▁▁▂▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8734</td></tr><tr><td>test_loss</td><td>0.36809</td></tr><tr><td>val_accuracy</td><td>0.88033</td></tr><tr><td>val_loss</td><td>0.35211</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_16_act_relu_opt_adam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ry4nqkyp' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ry4nqkyp</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_141840-ry4nqkyp/logs</code>
# wandb: Agent Starting Run: tv6k5jsb with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_142218-tv6k5jsb</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tv6k5jsb' target="_blank">bright-sweep-14</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tv6k5jsb' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tv6k5jsb</a>
# Run hl_5_bs_64_act_relu_opt_nadam finished with val_acc=0.8845, test_acc=0.8718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▄▆▆▆▇▇█</td></tr><tr><td>val_loss</td><td>█▆▄▄▂▂▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8718</td></tr><tr><td>test_loss</td><td>0.36534</td></tr><tr><td>val_accuracy</td><td>0.8845</td></tr><tr><td>val_loss</td><td>0.33541</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_5_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tv6k5jsb' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/tv6k5jsb</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_142218-tv6k5jsb/logs</code>
# wandb: Agent Starting Run: 16dxk1ys with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_142240-16dxk1ys</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/16dxk1ys' target="_blank">celestial-sweep-15</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/16dxk1ys' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/16dxk1ys</a>
# Run hl_5_bs_64_act_relu_opt_nadam finished with val_acc=0.8840, test_acc=0.8776
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂█▇▆██▇▇</td></tr><tr><td>val_loss</td><td>▇▇█▁▃▂▂▂▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8776</td></tr><tr><td>test_loss</td><td>0.37344</td></tr><tr><td>val_accuracy</td><td>0.884</td></tr><tr><td>val_loss</td><td>0.34085</td></tr></table><br/></div></div>
# ...
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.5
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_220034-2umv3y2e</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2umv3y2e' target="_blank">winter-sweep-346</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2umv3y2e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2umv3y2e</a>
# Run hl_4_bs_64_act_relu_opt_nadam finished with val_acc=0.8622, test_acc=0.8471
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▂▁▂▅▄▆▄▆▇█</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▃▅▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8471</td></tr><tr><td>test_loss</td><td>0.43663</td></tr><tr><td>val_accuracy</td><td>0.86217</td></tr><tr><td>val_loss</td><td>0.41008</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_4_bs_64_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2umv3y2e' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2umv3y2e</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_220034-2umv3y2e/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 4nsng00a with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_220248-4nsng00a</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4nsng00a' target="_blank">light-sweep-347</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4nsng00a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4nsng00a</a>
# Run hl_4_bs_32_act_tanh_opt_rmsprop finished with val_acc=0.8752, test_acc=0.8683
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅▇▅▆▇█▆</td></tr><tr><td>val_loss</td><td>█▅▅▃▂▄▃▂▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8683</td></tr><tr><td>test_loss</td><td>0.37786</td></tr><tr><td>val_accuracy</td><td>0.87517</td></tr><tr><td>val_loss</td><td>0.34681</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_4_bs_32_act_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4nsng00a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4nsng00a</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_220248-4nsng00a/logs</code>
# wandb: Agent Starting Run: rsu9741d with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_220343-rsu9741d</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/rsu9741d' target="_blank">spring-sweep-348</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/rsu9741d' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/rsu9741d</a>
# Run hl_4_bs_64_act_tanh_opt_nadam finished with val_acc=0.8822, test_acc=0.8734
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▇▇███▇▇</td></tr><tr><td>val_loss</td><td>█▄▄▃▂▁▁▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8734</td></tr><tr><td>test_loss</td><td>0.35035</td></tr><tr><td>val_accuracy</td><td>0.88217</td></tr><tr><td>val_loss</td><td>0.32136</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_4_bs_64_act_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/rsu9741d' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/rsu9741d</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_220343-rsu9741d/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 2ssp80za with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_220437-2ssp80za</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2ssp80za' target="_blank">curious-sweep-349</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2ssp80za' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2ssp80za</a>
# Run hl_4_bs_16_act_relu_opt_nadam finished with val_acc=0.8675, test_acc=0.8612
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇▇████</td></tr><tr><td>val_loss</td><td>█▅▃▃▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8612</td></tr><tr><td>test_loss</td><td>0.39161</td></tr><tr><td>val_accuracy</td><td>0.8675</td></tr><tr><td>val_loss</td><td>0.36751</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_4_bs_16_act_relu_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2ssp80za' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/2ssp80za</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_220437-2ssp80za/logs</code>
# wandb: Agent Starting Run: 4metx8yk with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layer_size: 128
# wandb: 	learning_rate: 0.001
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.0005
# wandb: 	weight_init: xavier
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250310_220501-4metx8yk</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4metx8yk' target="_blank">whole-sweep-350</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/sweeps/ysbgm4ic</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4metx8yk' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4metx8yk</a>
# Run hl_4_bs_32_act_sigmoid_opt_nadam finished with val_acc=0.8777, test_acc=0.8679
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▇▇▆▆██▇</td></tr><tr><td>val_loss</td><td>█▅▄▂▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>test_accuracy</td><td>0.8679</td></tr><tr><td>test_loss</td><td>0.36425</td></tr><tr><td>val_accuracy</td><td>0.87767</td></tr><tr><td>val_loss</td><td>0.33805</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_4_bs_32_act_sigmoid_opt_nadam</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4metx8yk' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/4metx8yk</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250310_220501-4metx8yk/logs</code>

# %% [markdown]
# # Q 5 : in report

# %% [markdown]
# # Q6

# %% [markdown]
# Best hyperparamters are :
# epoch:10
#
# weightinit: Xavier
#
# weight decay: 0
#
# optimiser:nadam
#
# no of hidden layers : 3
#
# learning rate:0.001
#
# activation function : relu
#
# batch size : 64
#
# hidden layer size :128

# %% [markdown]
# # Q7 : For the best model identified above, report the accuracy on the test set of fashion_mnist and plot the confusion matrix as shown below. More marks for creativity (less marks for producing the plot shown below as it is)

# %% [markdown]
# # Step 1 : Trains 'model' for 'num_epochs' using 'optimizer', logs a confusion matrix (and a normalized version) after each epoch, and prints/logs the validation accuracy.

# %%
(train_images_full, train_labels_full), (test_images, test_labels) = fashion_mnist.load_data()
val_split = int(0.1 * train_images_full.shape[0]) # 10% split

val_images = train_images_full[:val_split]
val_labels = train_labels_full[:val_split]
train_images = train_images_full[val_split:]
train_labels = train_labels_full[val_split:]

train_images = train_images.reshape(-1, 28*28) / 255.0
val_images   = val_images.reshape(-1, 28*28)   / 255.0
test_images  = test_images.reshape(-1, 28*28)  / 255.0

train_labels_oh = np.eye(10)[train_labels]
val_labels_oh   = np.eye(10)[val_labels]
test_labels_oh  = np.eye(10)[test_labels]

# %%
# Xavier/Glorot initialization.
def xavier_init(fan_in, fan_out):
    bound = np.sqrt(6 / (fan_in + fan_out))
    return np.random.uniform(-bound, bound, (fan_in, fan_out))

# %%
from sklearn.metrics import confusion_matrix

# %%
def train_and_log_confusion_matrix(model, optimizer, X_train, y_train_oh, X_val, y_val,num_epochs=10, batch_size=32, project_name="DLassignment1",run_name="Q7", class_names=None):
    # Initialize wandb run
    wandb.init(project=project_name, name=run_name, reinit=True)

    # Create default class names if not provided
    if class_names is None:
        num_classes = y_train_oh.shape[1]
        class_names = [f"Class {i}" for i in range(num_classes)]
    
    global_step = 1
    num_samples = X_train.shape[0]
    
    # Training loop over epochs
    for epoch in range(num_epochs):
        # Shuffle training data
        indices = np.random.permutation(num_samples)
        X_train_shuffled = X_train[indices]
        y_train_shuffled = y_train_oh[indices]
        
        epoch_loss = 0.0
        num_batches = num_samples // batch_size
        
        for i in range(num_batches):
            start = i * batch_size
            end = start + batch_size
            X_batch = X_train_shuffled[start:end]
            y_batch = y_train_shuffled[start:end]
            
            # forward pass using the updated method name
            y_pred = model.forward_pass(X_batch)
            
            # compute loss using the new method
            loss = model.compute_cost(y_pred, y_batch)
            epoch_loss += loss
            
            # backward pass: compute gradients using the new method
            dW, db = model.backpropagate(y_pred, y_batch)
            
            # optimizer update
            optimizer.update(model.weights, model.biases, dW, db, global_step)
            global_step += 1
        
        # average loss over all batches
        avg_loss = epoch_loss / num_batches
        
        # evaluate on validation set for accuracy
        val_pred_probs = model.forward_pass(X_val)
        val_predictions = np.argmax(val_pred_probs, axis=1)
        val_acc = np.mean(val_predictions == y_val)
        
        # Print epoch information
        print(f"Epoch {epoch+1}/{num_epochs} - Loss: {avg_loss:.4f} - Accuracy: {val_acc:.4f}")
        
        # log loss and accuracy metrics
        wandb.log({
            "val_loss": avg_loss,
            "val_accuracy": val_acc
        }, step=epoch+1)
    
    # after training, compute the final confusion matrices
    final_val_pred_probs = model.forward_pass(X_val)
    final_val_predictions = np.argmax(final_val_pred_probs, axis=1)
    
    # compute raw confusion matrix
    cm = confusion_matrix(y_val, final_val_predictions)
    # compute normalized confusion matrix (row-wise normalization)
    cm_normalized = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    
    # plot and log the raw confusion matrix
    fig, ax = plt.subplots(figsize=(6, 5))
    im = ax.imshow(cm, cmap='Spectral', interpolation='nearest')
    ax.set_title("Confusion Matrix")
    plt.colorbar(im, ax=ax)
    ax.set_ylabel("True Label")
    ax.set_xlabel("Predicted Label")
    
    threshold = cm.max() / 2.0
    for r in range(cm.shape[0]):
        for c in range(cm.shape[1]):
            ax.text(c, r, str(cm[r, c]),ha="center", va="center",color="white" if cm[r, c] > threshold else "black")
    plt.tight_layout()
    
    wandb.log({"confusion_matrix_plot": wandb.Image(fig)})
    plt.close(fig)
    
    # plot and log the normalized confusion matrix
    fig2, ax2 = plt.subplots(figsize=(6, 5))
    im2 = ax2.imshow(cm_normalized, cmap='plasma', interpolation='nearest', vmin=0, vmax=1)
    ax2.set_title("Normalized Confusion Matrix")
    plt.colorbar(im2, ax=ax2)
    ax2.set_ylabel("True Label")
    ax2.set_xlabel("Predicted Label")
    
    for r in range(cm_normalized.shape[0]):
        for c in range(cm_normalized.shape[1]):
            ax2.text(c, r, f"{cm_normalized[r, c]:.2f}",ha="center", va="center",color="white" if cm_normalized[r, c] > 0.5 else "black")
    plt.tight_layout()
    
    wandb.log({"confusion_matrix_plot_normalized": wandb.Image(fig2)})
    plt.close(fig2)
    
    # log an interactive confusion matrix using wandb's built-in functionality
    wandb.log({
        "final_confusion_matrix_interactive": wandb.plot.confusion_matrix(probs=None,y_true=y_val,preds=final_val_predictions,class_names=class_names)})
    
    wandb.finish()
    print("Training complete. Final confusion matrix logged!")

    
# Instantiate the NeuralNetwork and Nadam optimizer with updated parameters

best_model = NeuralNetwork(input_size=784,hidden_layers=3,hidden_units=128, output_size=10,init_method='xavier',activation_func='relu', reg_strength=0.0005)
my_optimizer = Nadam(lr=0.001, beta1=0.9, beta2=0.999)

train_and_log_confusion_matrix(model=best_model,optimizer=my_optimizer,X_train=train_images,y_train_oh=train_labels_oh,X_val=val_images, y_val=val_labels,num_epochs=10,batch_size=64,project_name="DLassignment1",
    run_name="Q7",class_names=["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"])
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁▆▆██</td></tr><tr><td>val_loss</td><td>█▄▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.88567</td></tr><tr><td>val_loss</td><td>0.30037</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q7</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ikw4l14h' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ikw4l14h</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_120048-ikw4l14h/logs</code>
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_120224-qc6c06ba</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qc6c06ba' target="_blank">Q7</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qc6c06ba' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qc6c06ba</a>
# Epoch 1/10 - Loss: 0.4881 - Accuracy: 0.8650
# Epoch 2/10 - Loss: 0.3646 - Accuracy: 0.8705
# Epoch 3/10 - Loss: 0.3282 - Accuracy: 0.8760
# Epoch 4/10 - Loss: 0.3084 - Accuracy: 0.8758
# Epoch 5/10 - Loss: 0.2902 - Accuracy: 0.8843
# Epoch 6/10 - Loss: 0.2767 - Accuracy: 0.8878
# Epoch 7/10 - Loss: 0.2664 - Accuracy: 0.8840
# Epoch 8/10 - Loss: 0.2536 - Accuracy: 0.8790
# Epoch 9/10 - Loss: 0.2433 - Accuracy: 0.8848
# Epoch 10/10 - Loss: 0.2358 - Accuracy: 0.8888
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁▃▄▄▇█▇▅▇█</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.88883</td></tr><tr><td>val_loss</td><td>0.23577</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Q7</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qc6c06ba' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/qc6c06ba</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_120224-qc6c06ba/logs</code>
# Training complete. Final confusion matrix logged!

# %% [markdown]
# Best hyperparamters are :
# epoch:10
#
# weightinit: Xavier
#
# weight decay: 0
#
# optimiser:nadam
#
# no of hidden layers : 3
#
# learning rate:0.001
#
# activation function : tanh
#
# batch size : 32
#
#
# hidden layer size :128

# %% [markdown]
# # Q8 : In all the models above you would have used cross entropy loss. Now compare the cross entropy loss with the squared error loss. I would again like to see some automatically generated plots or your own plots to convince me whether one is better than the other.

# %%
import math

class SimpleMLPWithLoss:
    def __init__(self, input_dim, num_hidden_layers, hidden_size, output_dim, weight_init='random', activation='relu', weight_decay=0.0, loss_type='cross_entropy'):
        self.num_hidden_layers = num_hidden_layers
        self.hidden_size = hidden_size
        self.weight_decay = weight_decay
        self.loss_type = loss_type
        
        # Set activation functions
        if activation == 'relu':
            self.activation = lambda x: np.maximum(0, x)
            self.activation_deriv = lambda x: (x > 0).astype(float)
        elif activation == 'sigmoid':
            self.activation = lambda x: 1.0 / (1.0 + np.exp(-x))
            self.activation_deriv = lambda x: self.activation(x) * (1 - self.activation(x))
        elif activation == 'tanh':
            self.activation = lambda x: np.tanh(x)
            self.activation_deriv = lambda x: 1 - np.tanh(x)**2
        else:
            raise ValueError("Unsupported activation")
        
        # Build network architecture
        layer_dims = [input_dim] + [hidden_size]*num_hidden_layers + [output_dim]
        self.weights = []
        self.biases  = []
        for i in range(len(layer_dims)-1):
            fan_in  = layer_dims[i]
            fan_out = layer_dims[i+1]
            if weight_init == 'xavier':
                W = xavier_init(fan_in, fan_out)
            else:
                W = np.random.randn(fan_in, fan_out) * 0.01
            b = np.zeros((1, fan_out))
            self.weights.append(W)
            self.biases.append(b)
    
    def softmax(self, x):
        exps = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exps / np.sum(exps, axis=1, keepdims=True)
    
    def forward(self, X):
        self.zs = []           # store linear combinations
        self.activations = [X]  # input activation
        A = X
        for i in range(len(self.weights)-1):
            z = A.dot(self.weights[i]) + self.biases[i]
            self.zs.append(z)
            A = self.activation(z)
            self.activations.append(A)
        # Output layer
        z = A.dot(self.weights[-1]) + self.biases[-1]
        self.zs.append(z)
        out = self.softmax(z)
        self.activations.append(out)
        return out
    
    def compute_loss(self, y_pred, y_true):
        m = y_true.shape[0]
        if self.loss_type == 'cross_entropy':
            loss = -np.sum(y_true * np.log(y_pred + 1e-8)) / m
        elif self.loss_type == 'squared_error':
            loss = 0.5 * np.sum((y_pred - y_true)**2) / m
        if self.weight_decay > 0:
            for W in self.weights:
                loss += (self.weight_decay / (2*m)) * np.sum(W**2)
        return loss
    
    def backward(self, y_pred, y_true):
        m = y_true.shape[0]
        # Compute delta for output layer
        if self.loss_type == 'cross_entropy':
            delta = (y_pred - y_true) / m
        elif self.loss_type == 'squared_error':
            delta = (y_pred - y_true) / m  # approximate gradient for squared error
        dW = [None] * len(self.weights)
        db = [None] * len(self.biases)
        
        # Output layer gradients
        dW[-1] = self.activations[-2].T.dot(delta)
        db[-1] = np.sum(delta, axis=0, keepdims=True)
        
        # Backpropagate through hidden layers
        for i in range(len(self.weights)-2, -1, -1):
            delta = delta.dot(self.weights[i+1].T) * self.activation_deriv(self.zs[i])
            dW[i] = self.activations[i].T.dot(delta)
            db[i] = np.sum(delta, axis=0, keepdims=True)
        
        if self.weight_decay > 0:
            for i in range(len(self.weights)):
                dW[i] += (self.weight_decay * self.weights[i]) / m
        
        return dW, db

# --- Optimizer Classes ---
# For this experiment we use Adam for both experiments.
class Adam:
    def __init__(self, learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
        self.learning_rate = learning_rate
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.mw = None
        self.vw = None
        self.mb = None
        self.vb = None
        
    def update(self, weights, biases, dW, db, t):
        if self.mw is None:
            self.mw = [np.zeros_like(w) for w in weights]
            self.vw = [np.zeros_like(w) for w in weights]
            self.mb = [np.zeros_like(b) for b in biases]
            self.vb = [np.zeros_like(b) for b in biases]
        for i in range(len(weights)):
            self.mw[i] = self.beta1 * self.mw[i] + (1 - self.beta1) * dW[i]
            self.vw[i] = self.beta2 * self.vw[i] + (1 - self.beta2) * (dW[i] ** 2)
            self.mb[i] = self.beta1 * self.mb[i] + (1 - self.beta1) * db[i]
            self.vb[i] = self.beta2 * self.vb[i] + (1 - self.beta2) * (db[i] ** 2)
            
            m_hat_w = self.mw[i] / (1 - self.beta1**t)
            v_hat_w = self.vw[i] / (1 - self.beta2**t)
            m_hat_b = self.mb[i] / (1 - self.beta1**t)
            v_hat_b = self.vb[i] / (1 - self.beta2**t)
            
            weights[i] -= self.learning_rate * m_hat_w / (np.sqrt(v_hat_w) + self.epsilon)
            biases[i]  -= self.learning_rate * m_hat_b / (np.sqrt(v_hat_b) + self.epsilon)

# %%
def train_model_experiment(loss_type, num_epochs, batch_size, learning_rate, model_params, optimizer_class):
    # Create model with specified loss type
    model = SimpleMLPWithLoss(input_dim=784, loss_type=loss_type, **model_params)
    optimizer = optimizer_class(learning_rate=learning_rate)
    
    train_losses = []
    val_losses = []
    val_accuracies = []
    global_step = 1
    num_samples = train_images.shape[0]
    
    for epoch in range(num_epochs):
        # Shuffle training data each epoch
        indices = np.random.permutation(num_samples)
        X_train_shuffled = train_images[indices]
        y_train_shuffled = train_labels_oh[indices]
        
        epoch_loss = 0.0
        num_batches = num_samples // batch_size
        
        for i in range(num_batches):
            start = i * batch_size
            end = start + batch_size
            X_batch = X_train_shuffled[start:end]
            y_batch = y_train_shuffled[start:end]
            
            # Forward pass
            y_pred = model.forward(X_batch)
            loss = model.compute_loss(y_pred, y_batch)
            epoch_loss += loss
            
            # Backward pass
            dW, db = model.backward(y_pred, y_batch)
            optimizer.update(model.weights, model.biases, dW, db, global_step)
            global_step += 1
        
        avg_train_loss = epoch_loss / num_batches
        train_losses.append(avg_train_loss)
        
        # Evaluate on validation set
        val_pred = model.forward(val_images)
        val_loss = model.compute_loss(val_pred, val_labels_oh)
        val_losses.append(val_loss)
        val_acc = np.mean(np.argmax(val_pred, axis=1) == val_labels)
        val_accuracies.append(val_acc)
        
        # Log metrics to wandb for this epoch
        wandb.log({"train_loss": avg_train_loss,"val_loss": val_loss,"val_accuracy": val_acc,"epoch": epoch+1})
        
        print(f"Loss type: {loss_type} | Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    
    return model, train_losses, val_losses, val_accuracies

# %%
# Common model parameters (adjust as needed)
model_params = {"num_hidden_layers": 3,"hidden_size": 128,"output_dim": 10,"weight_init": "xavier","activation": "relu","weight_decay": 0}

num_epochs = 10
batch_size = 64
learning_rate = 1e-3

# --- Experiment 1: Cross-Entropy Loss ---
print("Training with Cross-Entropy Loss:")
wandb.init(project="DLassignment1", name="Ques8e1", reinit=True)
model_ce, train_losses_ce, val_losses_ce, val_acc_ce = train_model_experiment(
    loss_type="cross_entropy",
    num_epochs=num_epochs,
    batch_size=batch_size,
    learning_rate=learning_rate,
    model_params=model_params,
    optimizer_class=Adam
)
wandb.finish()

# --- Experiment 2: Squared Error Loss ---
print("\nTraining with Squared Error Loss:")
wandb.init(project="DLassignment1", name="Ques8e2", reinit=True)
model_se, train_losses_se, val_losses_se, val_acc_se = train_model_experiment(
    loss_type="squared_error",
    num_epochs=num_epochs,
    batch_size=batch_size,
    learning_rate=learning_rate,
    model_params=model_params,
    optimizer_class=Adam
)
wandb.finish()
# Out:
# Training with Cross-Entropy Loss:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_121349-nghc3mna</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/nghc3mna' target="_blank">Ques8e1</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/nghc3mna' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/nghc3mna</a>
# Loss type: cross_entropy | Epoch 1/10 | Train Loss: 0.5030 | Val Loss: 0.3810 | Val Acc: 0.8658
# Loss type: cross_entropy | Epoch 2/10 | Train Loss: 0.3701 | Val Loss: 0.3484 | Val Acc: 0.8725
# Loss type: cross_entropy | Epoch 3/10 | Train Loss: 0.3350 | Val Loss: 0.3467 | Val Acc: 0.8727
# Loss type: cross_entropy | Epoch 4/10 | Train Loss: 0.3091 | Val Loss: 0.3355 | Val Acc: 0.8768
# Loss type: cross_entropy | Epoch 5/10 | Train Loss: 0.2918 | Val Loss: 0.3279 | Val Acc: 0.8780
# Loss type: cross_entropy | Epoch 6/10 | Train Loss: 0.2776 | Val Loss: 0.3265 | Val Acc: 0.8807
# Loss type: cross_entropy | Epoch 7/10 | Train Loss: 0.2645 | Val Loss: 0.3148 | Val Acc: 0.8873
# Loss type: cross_entropy | Epoch 8/10 | Train Loss: 0.2548 | Val Loss: 0.3186 | Val Acc: 0.8875
# Loss type: cross_entropy | Epoch 9/10 | Train Loss: 0.2452 | Val Loss: 0.3042 | Val Acc: 0.8868
# Loss type: cross_entropy | Epoch 10/10 | Train Loss: 0.2349 | Val Loss: 0.3308 | Val Acc: 0.8892
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▅▄▃▂▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▄▅▅▇▇▇█</td></tr><tr><td>val_loss</td><td>█▅▅▄▃▃▂▂▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.23495</td></tr><tr><td>val_accuracy</td><td>0.88917</td></tr><tr><td>val_loss</td><td>0.33081</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ques8e1</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/nghc3mna' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/nghc3mna</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_121349-nghc3mna/logs</code>
# Training with Squared Error Loss:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_121516-fw7387hq</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/fw7387hq' target="_blank">Ques8e2</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/fw7387hq' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/fw7387hq</a>
# Loss type: squared_error | Epoch 1/10 | Train Loss: 0.1312 | Val Loss: 0.1028 | Val Acc: 0.8537
# Loss type: squared_error | Epoch 2/10 | Train Loss: 0.0982 | Val Loss: 0.0967 | Val Acc: 0.8645
# Loss type: squared_error | Epoch 3/10 | Train Loss: 0.0893 | Val Loss: 0.0882 | Val Acc: 0.8750
# Loss type: squared_error | Epoch 4/10 | Train Loss: 0.0831 | Val Loss: 0.0847 | Val Acc: 0.8812
# Loss type: squared_error | Epoch 5/10 | Train Loss: 0.0789 | Val Loss: 0.0870 | Val Acc: 0.8755
# Loss type: squared_error | Epoch 6/10 | Train Loss: 0.0756 | Val Loss: 0.0834 | Val Acc: 0.8802
# Loss type: squared_error | Epoch 7/10 | Train Loss: 0.0722 | Val Loss: 0.0812 | Val Acc: 0.8867
# Loss type: squared_error | Epoch 8/10 | Train Loss: 0.0695 | Val Loss: 0.0800 | Val Acc: 0.8888
# Loss type: squared_error | Epoch 9/10 | Train Loss: 0.0666 | Val Loss: 0.0848 | Val Acc: 0.8802
# Loss type: squared_error | Epoch 10/10 | Train Loss: 0.0644 | Val Loss: 0.0830 | Val Acc: 0.8812
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▆▅▆██▆▆</td></tr><tr><td>val_loss</td><td>█▆▄▂▃▂▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.06438</td></tr><tr><td>val_accuracy</td><td>0.88117</td></tr><tr><td>val_loss</td><td>0.08297</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Ques8e2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/fw7387hq' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/fw7387hq</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_121516-fw7387hq/logs</code>

# %%
# wandb run for the comparison plot
wandb.init(project="DLasignment1", name="Comparison_Plot", reinit=True)

epochs = np.arange(1, num_epochs+1)

fig,ax = plt.subplots(figsize=(12, 5))


# Plot Validation Accuracy Comparison
ax.plot(epochs, val_acc_ce, marker='D', label="Cross Entropy" ,color='red')
ax.plot(epochs, val_acc_se, marker='d', label="Squared Error" , color='olive')
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation Accuracy")
ax.set_title("Validation Accuracy Comparison")
ax.legend()

plt.tight_layout()
plt.show()

# Log the comparison plot to wandb
wandb.log({"comparison_plot": wandb.Image(fig)})
wandb.finish()
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_122507-x0ojnzp2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1/runs/x0ojnzp2' target="_blank">Comparison_Plot</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLasignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1/runs/x0ojnzp2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLasignment1/runs/x0ojnzp2</a>
#  View run <strong style="color:#cdcd00">Comparison_Plot</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1/runs/x0ojnzp2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLasignment1/runs/x0ojnzp2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLasignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLasignment1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_122507-x0ojnzp2/logs</code>

# %% [markdown]
# # Q9 : link to github in report

# %% [markdown]
# # Q10 : Based on your learnings above, give me 3 recommendations for what would work for the MNIST dataset (not Fashion-MNIST). Just to be clear, I am asking you to take your learnings based on extensive experimentation with one dataset and see if these learnings help on another dataset. If I give you a budget of running only 3 hyperparameter configurations as opposed to the large number of experiments you have run above then which 3 would you use and why. Report the accuracies that you obtain using these 3 configurations.

# %% [markdown]
# # Step 1 : Import mnist dataset

# %%
from keras.datasets import mnist
import numpy as np

# Load MNIST dataset (handwritten digits)
(train_images_full_mnist, train_labels_full_mnist), (test_images_mnist, test_labels_mnist) = mnist.load_data()

# Split off 10% of training data as validation data
val_split = int(0.1 * train_images_full_mnist.shape[0])
val_images_mnist = train_images_full_mnist[:val_split]
val_labels_mnist = train_labels_full_mnist[:val_split]  # Corrected line
train_images_mnist = train_images_full_mnist[val_split:]
train_labels_mnist = train_labels_full_mnist[val_split:]

# Flatten images and normalize to [0, 1]
train_images_mnist = train_images_mnist.reshape(-1, 28*28) / 255.0
val_images_mnist = val_images_mnist.reshape(-1, 28*28) / 255.0
test_images_mnist = test_images_mnist.reshape(-1, 28*28) / 255.0

# One-hot encode training and validation labels
train_labels_mnist_oh = np.eye(10)[train_labels_mnist]
val_labels_mnist_oh = np.eye(10)[val_labels_mnist]
# Out:
# 2025-03-17 13:43:38.937453: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-17 13:43:38.950406: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-17 13:43:39.119181: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-17 13:43:39.299630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742199219.542999  112600 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742199219.592032  112600 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-17 13:43:39.964450: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def xavier_init(fan_in, fan_out):
    """Xavier/Glorot initialization."""
    limit = np.sqrt(6 / (fan_in + fan_out))
    return np.random.uniform(-limit, limit, (fan_in, fan_out))

# %%
class SimpleMLPWithLoss:
    def __init__(self, input_dim, num_hidden_layers, hidden_size, output_dim,
                 weight_init='random', activation='relu', weight_decay=0.0, loss_type='cross_entropy'):
        self.num_hidden_layers = num_hidden_layers
        self.hidden_size = hidden_size
        self.weight_decay = weight_decay
        self.loss_type = loss_type
        
        # Set activation function and derivative
        if activation == 'relu':
            self.activation = lambda x: np.maximum(0, x)
            self.activation_deriv = lambda x: (x > 0).astype(float)
        elif activation == 'sigmoid':
            self.activation = lambda x: 1.0 / (1.0 + np.exp(-x))
            self.activation_deriv = lambda x: self.activation(x) * (1 - self.activation(x))
        elif activation == 'tanh':
            self.activation = lambda x: np.tanh(x)
            self.activation_deriv = lambda x: 1 - np.tanh(x)**2
        else:
            raise ValueError("Unsupported activation")
        
        # Build network architecture: input -> hidden layers -> output
        layer_dims = [input_dim] + [hidden_size] * num_hidden_layers + [output_dim]
        self.weights = []
        self.biases = []
        for i in range(len(layer_dims) - 1):
            fan_in  = layer_dims[i]
            fan_out = layer_dims[i+1]
            if weight_init == 'xavier':
                W = xavier_init(fan_in, fan_out)
            else:
                W = np.random.randn(fan_in, fan_out) * 0.01
            b = np.zeros((1, fan_out))
            self.weights.append(W)
            self.biases.append(b)
    
    def softmax(self, x):
        exps = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exps / np.sum(exps, axis=1, keepdims=True)
    
    def forward(self, X):
        self.zs = []  # store pre-activations
        self.activations = [X]
        A = X
        for i in range(len(self.weights) - 1):
            z = A.dot(self.weights[i]) + self.biases[i]
            self.zs.append(z)
            A = self.activation(z)
            self.activations.append(A)
        # Output layer
        z = A.dot(self.weights[-1]) + self.biases[-1]
        self.zs.append(z)
        out = self.softmax(z)
        self.activations.append(out)
        return out
    
    def compute_loss(self, y_pred, y_true):
        m = y_true.shape[0]
        if self.loss_type == 'cross_entropy':
            loss = -np.sum(y_true * np.log(y_pred + 1e-8)) / m
        else:
            raise ValueError("This class supports only cross_entropy for this experiment.")
        # Add L2 regularization
        if self.weight_decay > 0:
            for W in self.weights:
                loss += (self.weight_decay / (2*m)) * np.sum(W**2)
        return loss
    
    def backward(self, y_pred, y_true):
        m = y_true.shape[0]
        # For cross-entropy with softmax, gradient is (y_pred - y_true)/m
        delta = (y_pred - y_true) / m
        dW = [None] * len(self.weights)
        db = [None] * len(self.biases)
        
        # Output layer gradients
        dW[-1] = self.activations[-2].T.dot(delta)
        db[-1] = np.sum(delta, axis=0, keepdims=True)
        
        # Backpropagate through hidden layers
        for i in range(len(self.weights)-2, -1, -1):
            delta = delta.dot(self.weights[i+1].T) * self.activation_deriv(self.zs[i])
            dW[i] = self.activations[i].T.dot(delta)
            db[i] = np.sum(delta, axis=0, keepdims=True)
        
        # Add L2 gradient
        if self.weight_decay > 0:
            for i in range(len(self.weights)):
                dW[i] += (self.weight_decay * self.weights[i]) / m
        
        return dW, db

# %%
def train_model_experiment(loss_type, num_epochs, batch_size, learning_rate, model_params, optimizer_class):
    model = SimpleMLPWithLoss(input_dim=784, loss_type=loss_type, **model_params)
    optimizer = optimizer_class(lr=learning_rate)
    
    train_losses = []
    val_losses = []
    val_accuracies = []
    global_step = 1
    num_samples = train_images_mnist.shape[0]
    
    # Initialize wandb run for this experiment
    wandb.init(project="DLassignment1", reinit=True, config={"loss_type": loss_type,"num_epochs": num_epochs,"batch_size": batch_size,"learning_rate": learning_rate,**model_params})
    
    for epoch in range(num_epochs):
        # Shuffle training data
        indices = np.random.permutation(num_samples)
        X_train_shuffled = train_images_mnist[indices]
        y_train_shuffled = train_labels_mnist_oh[indices]
        
        epoch_loss = 0.0
        num_batches = num_samples // batch_size
        
        for i in range(num_batches):
            start = i * batch_size
            end = start + batch_size
            X_batch = X_train_shuffled[start:end]
            y_batch = y_train_shuffled[start:end]
            
            # Forward pass
            y_pred = model.forward(X_batch)
            loss = model.compute_loss(y_pred, y_batch)
            epoch_loss += loss
            
            # Backward pass
            dW, db = model.backward(y_pred, y_batch)
            optimizer.update(model.weights, model.biases, dW, db, global_step)
            global_step += 1
        
        avg_train_loss = epoch_loss / num_batches
        train_losses.append(avg_train_loss)
        
        # Evaluate on validation set
        val_pred = model.forward(val_images_mnist)
        val_loss = model.compute_loss(val_pred, val_labels_mnist_oh)
        val_losses.append(val_loss)
        val_acc = np.mean(np.argmax(val_pred, axis=1) == val_labels_mnist)
        val_accuracies.append(val_acc)
        
        # Log metrics for this epoch to wandb
        wandb.log({"epoch": epoch+1,"train_loss": avg_train_loss, "val_loss": val_loss,"val_accuracy": val_acc})
        
        print(f"Loss type: {loss_type} | Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    
    wandb.finish()
    return model, train_losses, val_losses, val_accuracies

# %%
# Configuration 1
print("Running Configuration 1")
model_params1 = {"num_hidden_layers": 3,"hidden_size": 128,"output_dim": 10,"weight_init": "xavier","activation": "relu","weight_decay": 0}
model1, train_losses1, val_losses1, val_acc1 = train_model_experiment(loss_type="cross_entropy", num_epochs=10,batch_size=64,learning_rate=1e-3, model_params=model_params1,
    optimizer_class=Nadam)

# Configuration 2
print("\nRunning Configuration 2")
model_params2 = {"num_hidden_layers": 5,"hidden_size": 128,"output_dim": 10,"weight_init": "xavier","activation": "relu","weight_decay": 0.0005}
model2, train_losses2, val_losses2, val_acc2 = train_model_experiment(loss_type="cross_entropy", num_epochs=10,batch_size=32,learning_rate=1e-3,model_params=model_params2,
    optimizer_class=Nadam)

# Configuration 3
print("\nRunning Configuration 3")
model_params3 = {"num_hidden_layers": 4,"hidden_size": 128,"output_dim": 10,"weight_init": "xavier","activation": "relu","weight_decay": 0}
model3, train_losses3, val_losses3, val_acc3 = train_model_experiment(loss_type="cross_entropy",num_epochs=10,batch_size=64,learning_rate=1e-4, model_params=model_params3,
    optimizer_class=Nadam)
# Out:
# Running Configuration 1
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_134452-bqunqqpx</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bqunqqpx' target="_blank">dauntless-river-1143</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bqunqqpx' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bqunqqpx</a>
# Loss type: cross_entropy | Epoch 1/10 | Train Loss: 0.2624 | Val Loss: 0.1298 | Val Acc: 0.9598
# Loss type: cross_entropy | Epoch 2/10 | Train Loss: 0.1082 | Val Loss: 0.0970 | Val Acc: 0.9705
# Loss type: cross_entropy | Epoch 3/10 | Train Loss: 0.0740 | Val Loss: 0.0890 | Val Acc: 0.9743
# Loss type: cross_entropy | Epoch 4/10 | Train Loss: 0.0558 | Val Loss: 0.1034 | Val Acc: 0.9682
# Loss type: cross_entropy | Epoch 5/10 | Train Loss: 0.0447 | Val Loss: 0.0875 | Val Acc: 0.9745
# Loss type: cross_entropy | Epoch 6/10 | Train Loss: 0.0367 | Val Loss: 0.0895 | Val Acc: 0.9757
# Loss type: cross_entropy | Epoch 7/10 | Train Loss: 0.0312 | Val Loss: 0.0859 | Val Acc: 0.9772
# Loss type: cross_entropy | Epoch 8/10 | Train Loss: 0.0262 | Val Loss: 0.0892 | Val Acc: 0.9783
# Loss type: cross_entropy | Epoch 9/10 | Train Loss: 0.0234 | Val Loss: 0.1081 | Val Acc: 0.9743
# Loss type: cross_entropy | Epoch 10/10 | Train Loss: 0.0227 | Val Loss: 0.0870 | Val Acc: 0.9790
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▄▆▇▇█▆█</td></tr><tr><td>val_loss</td><td>█▃▁▄▁▂▁▂▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.02267</td></tr><tr><td>val_accuracy</td><td>0.979</td></tr><tr><td>val_loss</td><td>0.08699</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-river-1143</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bqunqqpx' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/bqunqqpx</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_134452-bqunqqpx/logs</code>
# Running Configuration 2
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_134750-ap9t476a</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ap9t476a' target="_blank">glamorous-valley-1144</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ap9t476a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ap9t476a</a>
# Loss type: cross_entropy | Epoch 1/10 | Train Loss: 0.2501 | Val Loss: 0.1230 | Val Acc: 0.9625
# Loss type: cross_entropy | Epoch 2/10 | Train Loss: 0.1218 | Val Loss: 0.1066 | Val Acc: 0.9693
# Loss type: cross_entropy | Epoch 3/10 | Train Loss: 0.0967 | Val Loss: 0.0919 | Val Acc: 0.9715
# Loss type: cross_entropy | Epoch 4/10 | Train Loss: 0.0790 | Val Loss: 0.1062 | Val Acc: 0.9692
# Loss type: cross_entropy | Epoch 5/10 | Train Loss: 0.0700 | Val Loss: 0.0975 | Val Acc: 0.9760
# Loss type: cross_entropy | Epoch 6/10 | Train Loss: 0.0618 | Val Loss: 0.0885 | Val Acc: 0.9765
# Loss type: cross_entropy | Epoch 7/10 | Train Loss: 0.0554 | Val Loss: 0.0955 | Val Acc: 0.9738
# Loss type: cross_entropy | Epoch 8/10 | Train Loss: 0.0534 | Val Loss: 0.0839 | Val Acc: 0.9775
# Loss type: cross_entropy | Epoch 9/10 | Train Loss: 0.0464 | Val Loss: 0.0978 | Val Acc: 0.9763
# Loss type: cross_entropy | Epoch 10/10 | Train Loss: 0.0483 | Val Loss: 0.0920 | Val Acc: 0.9775
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▄▇█▆█▇█</td></tr><tr><td>val_loss</td><td>█▅▂▅▃▂▃▁▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.04829</td></tr><tr><td>val_accuracy</td><td>0.9775</td></tr><tr><td>val_loss</td><td>0.09196</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glamorous-valley-1144</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ap9t476a' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ap9t476a</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_134750-ap9t476a/logs</code>
# Running Configuration 3
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_135511-aq910lgj</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/aq910lgj' target="_blank">grateful-snowball-1145</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/aq910lgj' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/aq910lgj</a>
# Loss type: cross_entropy | Epoch 1/10 | Train Loss: 0.6299 | Val Loss: 0.2520 | Val Acc: 0.9307
# Loss type: cross_entropy | Epoch 2/10 | Train Loss: 0.2337 | Val Loss: 0.1892 | Val Acc: 0.9493
# Loss type: cross_entropy | Epoch 3/10 | Train Loss: 0.1810 | Val Loss: 0.1590 | Val Acc: 0.9552
# Loss type: cross_entropy | Epoch 4/10 | Train Loss: 0.1490 | Val Loss: 0.1441 | Val Acc: 0.9593
# Loss type: cross_entropy | Epoch 5/10 | Train Loss: 0.1275 | Val Loss: 0.1319 | Val Acc: 0.9643
# Loss type: cross_entropy | Epoch 6/10 | Train Loss: 0.1102 | Val Loss: 0.1182 | Val Acc: 0.9663
# Loss type: cross_entropy | Epoch 7/10 | Train Loss: 0.0972 | Val Loss: 0.1062 | Val Acc: 0.9693
# Loss type: cross_entropy | Epoch 8/10 | Train Loss: 0.0847 | Val Loss: 0.1037 | Val Acc: 0.9698
# Loss type: cross_entropy | Epoch 9/10 | Train Loss: 0.0761 | Val Loss: 0.0970 | Val Acc: 0.9720
# Loss type: cross_entropy | Epoch 10/10 | Train Loss: 0.0681 | Val Loss: 0.0935 | Val Acc: 0.9718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train_loss</td><td>0.06815</td></tr><tr><td>val_accuracy</td><td>0.97183</td></tr><tr><td>val_loss</td><td>0.09355</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grateful-snowball-1145</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/aq910lgj' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/aq910lgj</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_135511-aq910lgj/logs</code>

# %%
wandb.init(project="DLassignment1", name="Q10", reinit=True)

epochs = np.arange(1, 11)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot Validation Loss Comparison
ax1.plot(epochs, val_losses1, marker='D', label="Config 1",color="cyan")
ax1.plot(epochs, val_losses2, marker='*', label="Config 2",color="red")
ax1.plot(epochs, val_losses3, marker='o', label="Config 3",color="blue")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Validation Loss")
ax1.set_title("Validation Loss Comparison")
ax1.legend()

# Plot Validation Accuracy Comparison
ax2.plot(epochs, val_acc1, marker='D', label="Config 1" , color="red")
ax2.plot(epochs, val_acc2, marker='*', label="Config 2", color="blue")
ax2.plot(epochs, val_acc3, marker='o', label="Config 3",color="cyan")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Validation Accuracy")
ax2.set_title("Validation Accuracy Comparison")
ax2.legend()

plt.tight_layout()
plt.show()

wandb.log({"mnist_comparison_plot": wandb.Image(plt.gcf())})
wandb.finish()

# Print final validation accuracies (as proxy for test accuracy)
print("Final Validation Accuracies:")
print(f"Configuration 1: {val_acc1[-1]*100:.2f}%")
print(f"Configuration 2: {val_acc2[-1]*100:.2f}%")
print(f"Configuration 3: {val_acc3[-1]*100:.2f}%")
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/snehal/Downloads/dl_ass1/wandb/run-20250317_135650-ollh8vce</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ollh8vce' target="_blank">Q10</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ollh8vce' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ollh8vce</a>
#  View run <strong style="color:#cdcd00">Q10</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ollh8vce' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1/runs/ollh8vce</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/DLassignment1' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/DLassignment1</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250317_135650-ollh8vce/logs</code>
# Final Validation Accuracies:
# Configuration 1: 97.90%
# Configuration 2: 97.75%
# Configuration 3: 97.18%
